# %%
from google.colab import drive

drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/tts_hifiGAN/hifi-gan
# Out:
# /content/drive/MyDrive/tts_hifiGAN/hifi-gan

# %%
# %cd drive/MyDrive/tts_hifiGAN/hifi-gan
# !pip install -r requirements.txt
# !pip install -q unidecode tensorboardX
# !pip install numba==0.48

# %% [markdown]
# ### library

# %%
"""import os
# os.chdir('/content')
# %cd drive/MyDrive/tts_hifiGAN
# !git clone https://github.com/jik876/hifi-gan.git

# !pip install -q unidecode tensorboardX
# %cd hifi-gan
# !pip install -r requirements.txt 
# !pip install numba==0.48"""

# %%
# terminal implement

# !pip install kora
from kora import console
console.start()

# %%
import easydict
import itertools
import os
import time
import argparse
import json
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import Conv1d, ConvTranspose1d, AvgPool1d, Conv2d
from torch.nn.utils import weight_norm, remove_weight_norm, spectral_norm
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import DistributedSampler, DataLoader
import torch.multiprocessing as mp
from torch.distributed import init_process_group
from torch.nn.parallel import DistributedDataParallel
from env import AttrDict, build_env
from meldataset import MelDataset, mel_spectrogram, get_dataset_filelist
from models import Generator, MultiPeriodDiscriminator, MultiScaleDiscriminator, feature_loss, generator_loss,\
    discriminator_loss
from utils import plot_spectrogram, scan_checkpoint, load_checkpoint, save_checkpoint, init_weights, get_padding

# %% [markdown]
# ### Training

# %%
a = easydict.EasyDict({ "group_name": None , 
                        "input_wavs_dir": "/content/drive/MyDrive/tts_hifiGAN/dataset/wav_data",
                        "input_mels_dir": "/content/drive/MyDrive/tts_hifiGAN/dataset/ft_dataset", # 노 쓸모
                        "input_training_file":"/content/drive/MyDrive/tts_hifiGAN/dataset/jss_text.tsv", # 노 쓸모
                        "input_validation_file": "/content/drive/MyDrive/tts_hifiGAN/dataset/jss_text.tsv", # 노 쓸모
                        "checkpoint_path": "cp_hifigan",
                        "config":"config_v1.json",
                        "training_epochs":3000,
                        "stdout_interval":5,
                        "checkpoint_interval":4000,
                        "summary_interval":100,
                        "validation_interval":1000,
                        "fine_tuning":False})

with open(a.config) as f:
    data = f.read()

# %%
training_files = [os.path.join(a.input_wavs_dir, f'{i}.wav') for i in range(9500)]
validation_files = [os.path.join(a.input_wavs_dir, f'{i}.wav') for i in range(9500,10000)]

training_filelist, validation_filelist = training_files, validation_files

# %%
json_config = json.loads(data)
h = AttrDict(json_config)
build_env(a.config, 'config.json', a.checkpoint_path)

torch.manual_seed(h.seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(h.seed)
    h.num_gpus = torch.cuda.device_count()
    h.batch_size = int(h.batch_size / h.num_gpus)
    print('Batch size per GPU :', h.batch_size)
else:
    pass
# Out:
# Batch size per GPU : 16

# %%
training_filelist, validation_filelist = training_files, validation_files

trainset = MelDataset(training_filelist, h.segment_size, h.n_fft, h.num_mels,
                      h.hop_size, h.win_size, h.sampling_rate, h.fmin, h.fmax, n_cache_reuse=0,
                      shuffle=False if h.num_gpus > 1 else True, fmax_loss=h.fmax_for_loss, device='cpu',
                      fine_tuning=a.fine_tuning, base_mels_path=a.input_mels_dir)

# %%
torch.backends.cudnn.benchmark = True


def train(rank, a, h):

    wandb.config.update(json_config)
    if h.num_gpus > 1:
        init_process_group(backend=h.dist_config['dist_backend'], init_method=h.dist_config['dist_url'],
                           world_size=h.dist_config['world_size'] * h.num_gpus, rank=rank)

    torch.cuda.manual_seed(h.seed)
    device = torch.device('cuda:{:d}'.format(rank))

    generator = Generator(h).to(device)
    mpd = MultiPeriodDiscriminator().to(device)
    msd = MultiScaleDiscriminator().to(device)

    wandb.watch(generator)
    wandb.watch(mpd)
    wandb.watch(msd)

    if rank == 0:
        print(generator)
        os.makedirs(a.checkpoint_path, exist_ok=True)
        print("checkpoints directory : ", a.checkpoint_path)

    if os.path.isdir(a.checkpoint_path):
        cp_g = scan_checkpoint(a.checkpoint_path, 'g_')
        cp_do = scan_checkpoint(a.checkpoint_path, 'do_')

    steps = 0
    if cp_g is None or cp_do is None:
        state_dict_do = None
        last_epoch = -1
    else:
        state_dict_g = load_checkpoint(cp_g, device)
        state_dict_do = load_checkpoint(cp_do, device)
        generator.load_state_dict(state_dict_g['generator'])
        mpd.load_state_dict(state_dict_do['mpd'])
        msd.load_state_dict(state_dict_do['msd'])
        steps = state_dict_do['steps'] + 1
        last_epoch = state_dict_do['epoch']

    if h.num_gpus > 1:
        generator = DistributedDataParallel(generator, device_ids=[rank]).to(device)
        mpd = DistributedDataParallel(mpd, device_ids=[rank]).to(device)
        msd = DistributedDataParallel(msd, device_ids=[rank]).to(device)

    optim_g = torch.optim.AdamW(generator.parameters(), h.learning_rate, betas=[h.adam_b1, h.adam_b2])
    optim_d = torch.optim.AdamW(itertools.chain(msd.parameters(), mpd.parameters()),
                                h.learning_rate, betas=[h.adam_b1, h.adam_b2])

    if state_dict_do is not None:
        optim_g.load_state_dict(state_dict_do['optim_g'])
        optim_d.load_state_dict(state_dict_do['optim_d'])

    scheduler_g = torch.optim.lr_scheduler.ExponentialLR(optim_g, gamma=h.lr_decay, last_epoch=last_epoch)
    scheduler_d = torch.optim.lr_scheduler.ExponentialLR(optim_d, gamma=h.lr_decay, last_epoch=last_epoch)

    # training_filelist, validation_filelist = get_dataset_filelist(a)
    training_filelist, validation_filelist = training_files, validation_files

    trainset = MelDataset(training_filelist, h.segment_size, h.n_fft, h.num_mels,
                          h.hop_size, h.win_size, h.sampling_rate, h.fmin, h.fmax, n_cache_reuse=0,
                          shuffle=False if h.num_gpus > 1 else True, fmax_loss=h.fmax_for_loss, device=device,
                          fine_tuning=a.fine_tuning, base_mels_path=a.input_mels_dir)

    train_sampler = DistributedSampler(trainset) if h.num_gpus > 1 else None

    train_loader = DataLoader(trainset, num_workers=h.num_workers, shuffle=False,
                              sampler=train_sampler,
                              batch_size=h.batch_size,
                              pin_memory=True,
                              drop_last=True)

    if rank == 0:
        validset = MelDataset(validation_filelist, h.segment_size, h.n_fft, h.num_mels,
                              h.hop_size, h.win_size, h.sampling_rate, h.fmin, h.fmax, False, False, n_cache_reuse=0,
                              fmax_loss=h.fmax_for_loss, device=device, fine_tuning=a.fine_tuning,
                              base_mels_path=a.input_mels_dir)
        
        #validset = MelDataset(validation_filelist, h.segment_size, h.n_fft, h.num_mels,
        #              h.hop_size, h.win_size, h.sampling_rate, h.fmin, h.fmax, n_cache_reuse=0,
        #              shuffle=False, fmax_loss=h.fmax_for_loss, device=device,
        #              fine_tuning=a.fine_tuning, base_mels_path=a.input_mels_dir)
        
        validation_loader = DataLoader(validset, num_workers=1, shuffle=False,
                                       sampler=None,
                                       batch_size=1,
                                       pin_memory=True,
                                       drop_last=True)

        sw = SummaryWriter(os.path.join(a.checkpoint_path, 'logs'))

    generator.train()
    mpd.train()
    msd.train()
    for epoch in range(max(0, last_epoch), a.training_epochs):
        if rank == 0:
            start = time.time()
            print("Epoch: {}".format(epoch+1))

        if h.num_gpus > 1:
            train_sampler.set_epoch(epoch)

        for i, batch in enumerate(train_loader):
            if rank == 0:
                start_b = time.time()
            x, y, _, y_mel = batch
            x = torch.autograd.Variable(x.to(device, non_blocking=True))
            y = torch.autograd.Variable(y.to(device, non_blocking=True))
            y_mel = torch.autograd.Variable(y_mel.to(device, non_blocking=True))
            y = y.unsqueeze(1)

            y_g_hat = generator(x)
            y_g_hat_mel = mel_spectrogram(y_g_hat.squeeze(1), h.n_fft, h.num_mels, h.sampling_rate, h.hop_size, h.win_size,
                                          h.fmin, h.fmax_for_loss)

            optim_d.zero_grad()

            # MPD
            y_df_hat_r, y_df_hat_g, _, _ = mpd(y, y_g_hat.detach())
            loss_disc_f, losses_disc_f_r, losses_disc_f_g = discriminator_loss(y_df_hat_r, y_df_hat_g)

            # MSD
            y_ds_hat_r, y_ds_hat_g, _, _ = msd(y, y_g_hat.detach())
            loss_disc_s, losses_disc_s_r, losses_disc_s_g = discriminator_loss(y_ds_hat_r, y_ds_hat_g)

            loss_disc_all = loss_disc_s + loss_disc_f

            loss_disc_all.backward()
            optim_d.step()

            # Generator
            optim_g.zero_grad()

            # L1 Mel-Spectrogram Loss
            loss_mel = F.l1_loss(y_mel, y_g_hat_mel) * 45

            y_df_hat_r, y_df_hat_g, fmap_f_r, fmap_f_g = mpd(y, y_g_hat)
            y_ds_hat_r, y_ds_hat_g, fmap_s_r, fmap_s_g = msd(y, y_g_hat)
            loss_fm_f = feature_loss(fmap_f_r, fmap_f_g)
            loss_fm_s = feature_loss(fmap_s_r, fmap_s_g)
            loss_gen_f, losses_gen_f = generator_loss(y_df_hat_g)
            loss_gen_s, losses_gen_s = generator_loss(y_ds_hat_g)
            loss_gen_all = loss_gen_s + loss_gen_f + loss_fm_s + loss_fm_f + loss_mel

            # print('loss_gen_all: ', loss_gen_all)
            
            loss_gen_all.backward()
            optim_g.step()

            if rank == 0:
                # STDOUT logging
                if steps % a.stdout_interval == 0:
                    with torch.no_grad():
                        mel_error = F.l1_loss(y_mel, y_g_hat_mel).item()

                    print('Steps : {:d}, Gen Loss Total : {:4.3f}, Mel-Spec. Error : {:4.3f}, s/b : {:4.3f}'.
                          format(steps, loss_gen_all, mel_error, time.time() - start_b))
                    
                    wandb.log({'loss_gen_all':loss_gen_all,
                               'mel_error':mel_error})

                # checkpointing
                if steps % a.checkpoint_interval == 0 and steps != 0:
                    checkpoint_path = "{}/g_{:08d}".format(a.checkpoint_path, steps)
                    save_checkpoint(checkpoint_path,
                                    {'generator': (generator.module if h.num_gpus > 1 else generator).state_dict()})
                    checkpoint_path = "{}/do_{:08d}".format(a.checkpoint_path, steps)
                    save_checkpoint(checkpoint_path, 
                                    {'mpd': (mpd.module if h.num_gpus > 1
                                                         else mpd).state_dict(),
                                     'msd': (msd.module if h.num_gpus > 1
                                                         else msd).state_dict(),
                                     'optim_g': optim_g.state_dict(), 'optim_d': optim_d.state_dict(), 'steps': steps,
                                     'epoch': epoch})

                # Tensorboard summary logging
                if steps % a.summary_interval == 0:
                    sw.add_scalar("training/gen_loss_total", loss_gen_all, steps)
                    sw.add_scalar("training/mel_spec_error", mel_error, steps)

                # Validation
                if steps % a.validation_interval == 0:  # and steps != 0:
                    generator.eval()
                    torch.cuda.empty_cache()
                    val_err_tot = 0
                    with torch.no_grad():
                        for j, batch in enumerate(validation_loader):

                            # y = y.unsqueeze(1)
            
                            x, y, _, y_mel = batch
                            
                            x = torch.autograd.Variable(x.to(device,non_blocking=True))
                            y = torch.autograd.Variable(y.to(device,non_blocking=True))
                            y_mel = torch.autograd.Variable(y_mel.to(device, non_blocking=True))
                    
                            y_g_hat = generator(x)
            
                            # y_g_hat = generator(x.to(device))

                            y_g_hat_mel = mel_spectrogram(y_g_hat.squeeze(1), h.n_fft, h.num_mels, h.sampling_rate, h.hop_size, h.win_size,
                                                          h.fmin, h.fmax_for_loss)
                            

                            val_err_tot += F.l1_loss(y_mel, y_g_hat_mel).item()
                            
                            

                            if j <= 4:
                                if steps == 0:
                                    sw.add_audio('gt/y_{}'.format(j), y[0], steps, h.sampling_rate)
                                    sw.add_figure('gt/y_spec_{}'.format(j), plot_spectrogram(x.cpu().numpy()[0]), steps)

        

                                sw.add_audio('generated/y_hat_{}'.format(j), y_g_hat[0], steps, h.sampling_rate)
 
                                y_hat_spec = mel_spectrogram(y_g_hat.squeeze(1), h.n_fft, h.num_mels,
                                                             h.sampling_rate, h.hop_size, h.win_size,
                                                             h.fmin, h.fmax)

                                sw.add_figure('generated/y_hat_spec_{}'.format(j),
                                              plot_spectrogram(y_hat_spec.squeeze(0).cpu().numpy()), steps)


                        val_err = val_err_tot / (j+1)
                        wandb.log({'val_err':val_err})
                        print('val err tot: ',val_err)
                        sw.add_scalar("validation/mel_spec_error", val_err, steps)

                    generator.train()

            steps += 1

        scheduler_g.step()
        scheduler_d.step()
        if rank == 0:
            print('Time taken for epoch {} is {} sec\n'.format(epoch + 1, int(time.time() - start)))

# %%
# !pip install --upgrade wandb -qq

import wandb
wandb.login()
wandb.init(project="TTS-vocoder-pretrain", name='hifi-gan')
# Out:
#      |████████████████████████████████| 1.8 MB 30.4 MB/s
#      |████████████████████████████████| 146 kB 72.9 MB/s
#      |████████████████████████████████| 181 kB 22.9 MB/s
#      |████████████████████████████████| 63 kB 2.0 MB/s
#   Building wheel for pathtools (setup.py) ... done
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: keonwookim. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/content/drive/MyDrive/tts_hifiGAN/hifi-gan/wandb/run-20220713_050204-3r16uu7b</code>
# Syncing run <strong><a href="https://wandb.ai/keonwookim/TTS-vocoder-pretrain/runs/3r16uu7b" target="_blank">hifi-gan</a></strong> to <a href="https://wandb.ai/keonwookim/TTS-vocoder-pretrain" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/keonwookim/TTS-vocoder-pretrain/runs/3r16uu7b?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
train(0, a, h)
# Out:
# Generator(
#   (conv_pre): Conv1d(80, 512, kernel_size=(7,), stride=(1,), padding=(3,))
#   (ups): ModuleList(
#     (0): ConvTranspose1d(512, 256, kernel_size=(16,), stride=(8,), padding=(4,))
#     (1): ConvTranspose1d(256, 128, kernel_size=(16,), stride=(8,), padding=(4,))
#     (2): ConvTranspose1d(128, 64, kernel_size=(4,), stride=(2,), padding=(1,))
#     (3): ConvTranspose1d(64, 32, kernel_size=(4,), stride=(2,), padding=(1,))
#   )
#   (resblocks): ModuleList(
#     (0): ResBlock1(
#       (convs1): ModuleList(
#         (0): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,))
#         (2): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,))
#       )
#       (convs2): ModuleList(
#         (0): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         (2): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#     )
#     (1): ResBlock1(
#       (convs1): ModuleList(
#         (0): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(3,))
#         (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#         (2): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(15,), dilation=(5,))
#       )
#       (convs2): ModuleList(
#         (0): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(3,))
#         (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(3,))
#         (2): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(3,))
#       )
#     )
#     (2): ResBlock1(
#       (convs1): ModuleList(
#         (0): Conv1d(256, 256, kernel_size=(11,), stride=(1,), padding=(5,))
#         (1): Conv1d(256, 256, kernel_size=(11,), stride=(1,), padding=(15,), dilation=(3,))
#         (2): Conv1d(256, 256, kernel_size=(11,), stride=(1,), padding=(25,), dilation=(5,))
#       )
#       (convs2): ModuleList(
#         (0): Conv1d(256, 256, kernel_size=(11,), stride=(1,), padding=(5,))
#         (1): Conv1d(256, 256, kernel_size=(11,), stride=(1,), padding=(5,))
#         (2): Conv1d(256, 256, kernel_size=(11,), stride=(1,), padding=(5,))
#       )
#     )
#     (3): ResBlock1(
#       (convs1): ModuleList(
#         (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,))
#         (2): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,))
#       )
#       (convs2): ModuleList(
#         (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#         (2): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#     )
#     (4): ResBlock1(
#       (convs1): ModuleList(
#         (0): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(3,))
#         (1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#         (2): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(15,), dilation=(5,))
#       )
#       (convs2): ModuleList(
#         (0): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(3,))
#         (1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(3,))
#         (2): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(3,))
#       )
#     )
#     (5): ResBlock1(
#       (convs1): ModuleList(
#         (0): Conv1d(128, 128, kernel_size=(11,), stride=(1,), padding=(5,))
#         (1): Conv1d(128, 128, kernel_size=(11,), stride=(1,), padding=(15,), dilation=(3,))
#         (2): Conv1d(128, 128, kernel_size=(11,), stride=(1,), padding=(25,), dilation=(5,))
#       )
#       (convs2): ModuleList(
#         (0): Conv1d(128, 128, kernel_size=(11,), stride=(1,), padding=(5,))
#         (1): Conv1d(128, 128, kernel_size=(11,), stride=(1,), padding=(5,))
#         (2): Conv1d(128, 128, kernel_size=(11,), stride=(1,), padding=(5,))
#       )
#     )
#     (6): ResBlock1(
#       (convs1): ModuleList(
#         (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,))
#         (2): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,))
#       )
#       (convs2): ModuleList(
#         (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#         (2): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#     )
#     (7): ResBlock1(
#       (convs1): ModuleList(
#         (0): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(3,))
#         (1): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#         (2): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(15,), dilation=(5,))
#       )
#       (convs2): ModuleList(
#         (0): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(3,))
#         (1): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(3,))
#         (2): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(3,))
#       )
#     )
#     (8): ResBlock1(
#       (convs1): ModuleList(
#         (0): Conv1d(64, 64, kernel_size=(11,), stride=(1,), padding=(5,))
#         (1): Conv1d(64, 64, kernel_size=(11,), stride=(1,), padding=(15,), dilation=(3,))
#         (2): Conv1d(64, 64, kernel_size=(11,), stride=(1,), padding=(25,), dilation=(5,))
#       )
#       (convs2): ModuleList(
#         (0): Conv1d(64, 64, kernel_size=(11,), stride=(1,), padding=(5,))
#         (1): Conv1d(64, 64, kernel_size=(11,), stride=(1,), padding=(5,))
#         (2): Conv1d(64, 64, kernel_size=(11,), stride=(1,), padding=(5,))
#       )
#     )
#     (9): ResBlock1(
#       (convs1): ModuleList(
#         (0): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,))
#         (2): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,))
#       )
#       (convs2): ModuleList(
#         (0): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#         (2): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#     )
#     (10): ResBlock1(
#       (convs1): ModuleList(
#         (0): Conv1d(32, 32, kernel_size=(7,), stride=(1,), padding=(3,))
#         (1): Conv1d(32, 32, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#         (2): Conv1d(32, 32, kernel_size=(7,), stride=(1,), padding=(15,), dilation=(5,))
#       )
#       (convs2): ModuleList(
#         (0): Conv1d(32, 32, kernel_size=(7,), stride=(1,), padding=(3,))
#         (1): Conv1d(32, 32, kernel_size=(7,), stride=(1,), padding=(3,))
#         (2): Conv1d(32, 32, kernel_size=(7,), stride=(1,), padding=(3,))
#       )
#     )
#     (11): ResBlock1(
#       (convs1): ModuleList(
#         (0): Conv1d(32, 32, kernel_size=(11,), stride=(1,), padding=(5,))
#         (1): Conv1d(32, 32, kernel_size=(11,), stride=(1,), padding=(15,), dilation=(3,))
#         (2): Conv1d(32, 32, kernel_size=(11,), stride=(1,), padding=(25,), dilation=(5,))
#       )
#       (convs2): ModuleList(
#         (0): Conv1d(32, 32, kernel_size=(11,), stride=(1,), padding=(5,))
#         (1): Conv1d(32, 32, kernel_size=(11,), stride=(1,), padding=(5,))
#         (2): Conv1d(32, 32, kernel_size=(11,), stride=(1,), padding=(5,))
#       )
#     )
#   )
#   (conv_post): Conv1d(32, 1, kernel_size=(7,), stride=(1,), padding=(3,))
# )
# checkpoints directory :  cp_hifigan
# Loading 'cp_hifigan/g_00196000'
# Complete.
# Loading 'cp_hifigan/do_00196000'
# Complete.
# Epoch: 324
# Steps : 196005, Gen Loss Total : 27.279, Mel-Spec. Error : 0.273, s/b : 1.686
# Steps : 196010, Gen Loss Total : 26.077, Mel-Spec. Error : 0.284, s/b : 1.677
# Steps : 196015, Gen Loss Total : 28.138, Mel-Spec. Error : 0.289, s/b : 1.698
# Steps : 196020, Gen Loss Total : 27.961, Mel-Spec. Error : 0.284, s/b : 1.701
# Steps : 196025, Gen Loss Total : 28.731, Mel-Spec. Error : 0.290, s/b : 1.764
# Steps : 196030, Gen Loss Total : 27.711, Mel-Spec. Error : 0.278, s/b : 1.703
# Steps : 196035, Gen Loss Total : 28.663, Mel-Spec. Error : 0.286, s/b : 1.714
# Steps : 196040, Gen Loss Total : 28.166, Mel-Spec. Error : 0.288, s/b : 1.785
# Steps : 196045, Gen Loss Total : 27.154, Mel-Spec. Error : 0.290, s/b : 1.724
# Steps : 196050, Gen Loss Total : 26.213, Mel-Spec. Error : 0.289, s/b : 1.719
# Steps : 196055, Gen Loss Total : 26.969, Mel-Spec. Error : 0.288, s/b : 1.732
# Steps : 196060, Gen Loss Total : 24.550, Mel-Spec. Error : 0.272, s/b : 1.797
# Steps : 196065, Gen Loss Total : 26.796, Mel-Spec. Error : 0.292, s/b : 1.733
# Steps : 196070, Gen Loss Total : 27.936, Mel-Spec. Error : 0.294, s/b : 1.822
# Steps : 196075, Gen Loss Total : 26.692, Mel-Spec. Error : 0.299, s/b : 1.742
# Steps : 196080, Gen Loss Total : 27.818, Mel-Spec. Error : 0.293, s/b : 1.819
# Steps : 196085, Gen Loss Total : 27.814, Mel-Spec. Error : 0.291, s/b : 1.736
# Steps : 196090, Gen Loss Total : 27.912, Mel-Spec. Error : 0.291, s/b : 1.835
# Steps : 196095, Gen Loss Total : 25.298, Mel-Spec. Error : 0.292, s/b : 1.751
# Steps : 196100, Gen Loss Total : 26.814, Mel-Spec. Error : 0.290, s/b : 1.835
# Steps : 196105, Gen Loss Total : 27.041, Mel-Spec. Error : 0.303, s/b : 1.750
# Steps : 196110, Gen Loss Total : 27.503, Mel-Spec. Error : 0.300, s/b : 1.746
# Steps : 196115, Gen Loss Total : 28.799, Mel-Spec. Error : 0.294, s/b : 1.750
# Steps : 196120, Gen Loss Total : 27.897, Mel-Spec. Error : 0.304, s/b : 1.803
# Steps : 196125, Gen Loss Total : 27.035, Mel-Spec. Error : 0.295, s/b : 1.745
# Steps : 196130, Gen Loss Total : 26.671, Mel-Spec. Error : 0.294, s/b : 1.733
# Steps : 196135, Gen Loss Total : 31.060, Mel-Spec. Error : 0.307, s/b : 1.757
# Steps : 196140, Gen Loss Total : 27.855, Mel-Spec. Error : 0.296, s/b : 1.835
# Steps : 196145, Gen Loss Total : 28.316, Mel-Spec. Error : 0.295, s/b : 1.741
# Steps : 196150, Gen Loss Total : 27.676, Mel-Spec. Error : 0.289, s/b : 1.748
# Steps : 196155, Gen Loss Total : 28.738, Mel-Spec. Error : 0.302, s/b : 1.753
# Steps : 196160, Gen Loss Total : 26.825, Mel-Spec. Error : 0.286, s/b : 1.741
# Steps : 196165, Gen Loss Total : 27.418, Mel-Spec. Error : 0.292, s/b : 1.824
# Steps : 196170, Gen Loss Total : 26.945, Mel-Spec. Error : 0.301, s/b : 1.748
# Steps : 196175, Gen Loss Total : 29.895, Mel-Spec. Error : 0.295, s/b : 1.754
# Steps : 196180, Gen Loss Total : 28.494, Mel-Spec. Error : 0.292, s/b : 1.747
# Steps : 196185, Gen Loss Total : 28.981, Mel-Spec. Error : 0.302, s/b : 1.745
# Steps : 196190, Gen Loss Total : 25.890, Mel-Spec. Error : 0.295, s/b : 1.749
# Steps : 196195, Gen Loss Total : 26.673, Mel-Spec. Error : 0.292, s/b : 1.757
# Steps : 196200, Gen Loss Total : 25.117, Mel-Spec. Error : 0.271, s/b : 1.748
# Steps : 196205, Gen Loss Total : 28.513, Mel-Spec. Error : 0.308, s/b : 1.816
# Steps : 196210, Gen Loss Total : 25.918, Mel-Spec. Error : 0.284, s/b : 1.746
# Steps : 196215, Gen Loss Total : 26.743, Mel-Spec. Error : 0.302, s/b : 1.760
# Steps : 196220, Gen Loss Total : 26.949, Mel-Spec. Error : 0.293, s/b : 1.761
# Steps : 196225, Gen Loss Total : 28.057, Mel-Spec. Error : 0.280, s/b : 1.752
# Steps : 196230, Gen Loss Total : 26.114, Mel-Spec. Error : 0.295, s/b : 1.748
# Steps : 196235, Gen Loss Total : 26.523, Mel-Spec. Error : 0.294, s/b : 1.760
# Steps : 196240, Gen Loss Total : 28.824, Mel-Spec. Error : 0.296, s/b : 1.759
# Steps : 196245, Gen Loss Total : 26.410, Mel-Spec. Error : 0.292, s/b : 1.747
# Steps : 196250, Gen Loss Total : 28.630, Mel-Spec. Error : 0.289, s/b : 1.826
# Steps : 196255, Gen Loss Total : 27.858, Mel-Spec. Error : 0.279, s/b : 1.761
# Steps : 196260, Gen Loss Total : 27.652, Mel-Spec. Error : 0.300, s/b : 1.763
# Steps : 196265, Gen Loss Total : 27.678, Mel-Spec. Error : 0.284, s/b : 1.753
# Steps : 196270, Gen Loss Total : 26.174, Mel-Spec. Error : 0.280, s/b : 1.754
# Steps : 196275, Gen Loss Total : 25.081, Mel-Spec. Error : 0.273, s/b : 1.759
# Steps : 196280, Gen Loss Total : 26.528, Mel-Spec. Error : 0.284, s/b : 1.754
# Steps : 196285, Gen Loss Total : 29.192, Mel-Spec. Error : 0.297, s/b : 1.752
# Steps : 196290, Gen Loss Total : 28.526, Mel-Spec. Error : 0.296, s/b : 1.759
# Steps : 196295, Gen Loss Total : 26.159, Mel-Spec. Error : 0.295, s/b : 1.757
# Steps : 196300, Gen Loss Total : 26.956, Mel-Spec. Error : 0.287, s/b : 1.842
# Steps : 196305, Gen Loss Total : 27.234, Mel-Spec. Error : 0.298, s/b : 1.747
# Steps : 196310, Gen Loss Total : 24.806, Mel-Spec. Error : 0.267, s/b : 1.745
# Steps : 196315, Gen Loss Total : 28.525, Mel-Spec. Error : 0.295, s/b : 1.757
# Steps : 196320, Gen Loss Total : 26.731, Mel-Spec. Error : 0.293, s/b : 1.859
# Steps : 196325, Gen Loss Total : 28.315, Mel-Spec. Error : 0.299, s/b : 1.754
# Steps : 196330, Gen Loss Total : 30.948, Mel-Spec. Error : 0.318, s/b : 1.750
# Steps : 196335, Gen Loss Total : 27.280, Mel-Spec. Error : 0.292, s/b : 1.763
# Steps : 196340, Gen Loss Total : 27.951, Mel-Spec. Error : 0.303, s/b : 1.847
# Steps : 196345, Gen Loss Total : 28.589, Mel-Spec. Error : 0.305, s/b : 1.755
# Steps : 196350, Gen Loss Total : 26.462, Mel-Spec. Error : 0.295, s/b : 1.747
# Steps : 196355, Gen Loss Total : 29.273, Mel-Spec. Error : 0.303, s/b : 1.758
# Steps : 196360, Gen Loss Total : 30.844, Mel-Spec. Error : 0.307, s/b : 1.827
# Steps : 196365, Gen Loss Total : 26.221, Mel-Spec. Error : 0.295, s/b : 1.749
# Steps : 196370, Gen Loss Total : 28.480, Mel-Spec. Error : 0.304, s/b : 1.752
# Steps : 196375, Gen Loss Total : 29.275, Mel-Spec. Error : 0.297, s/b : 1.767
# Steps : 196380, Gen Loss Total : 30.231, Mel-Spec. Error : 0.311, s/b : 1.756
# Steps : 196385, Gen Loss Total : 29.483, Mel-Spec. Error : 0.291, s/b : 1.857
# Steps : 196390, Gen Loss Total : 27.315, Mel-Spec. Error : 0.304, s/b : 1.758
# Steps : 196395, Gen Loss Total : 27.668, Mel-Spec. Error : 0.286, s/b : 1.763
# Steps : 196400, Gen Loss Total : 27.236, Mel-Spec. Error : 0.290, s/b : 1.753
# Steps : 196405, Gen Loss Total : 28.071, Mel-Spec. Error : 0.278, s/b : 1.834
# Steps : 196410, Gen Loss Total : 27.421, Mel-Spec. Error : 0.295, s/b : 1.750
# Steps : 196415, Gen Loss Total : 26.133, Mel-Spec. Error : 0.283, s/b : 1.762
# Steps : 196420, Gen Loss Total : 28.631, Mel-Spec. Error : 0.302, s/b : 1.755
# Steps : 196425, Gen Loss Total : 24.600, Mel-Spec. Error : 0.288, s/b : 1.820
# Steps : 196430, Gen Loss Total : 26.870, Mel-Spec. Error : 0.296, s/b : 1.757
# Steps : 196435, Gen Loss Total : 27.144, Mel-Spec. Error : 0.292, s/b : 1.760
# Steps : 196440, Gen Loss Total : 27.972, Mel-Spec. Error : 0.292, s/b : 1.750
# Steps : 196445, Gen Loss Total : 28.016, Mel-Spec. Error : 0.284, s/b : 1.814
# Steps : 196450, Gen Loss Total : 26.866, Mel-Spec. Error : 0.287, s/b : 1.754
# Steps : 196455, Gen Loss Total : 27.749, Mel-Spec. Error : 0.295, s/b : 1.755
# Steps : 196460, Gen Loss Total : 28.702, Mel-Spec. Error : 0.306, s/b : 1.755
# Steps : 196465, Gen Loss Total : 25.896, Mel-Spec. Error : 0.297, s/b : 1.828
# Steps : 196470, Gen Loss Total : 28.364, Mel-Spec. Error : 0.294, s/b : 1.744
# Steps : 196475, Gen Loss Total : 26.669, Mel-Spec. Error : 0.292, s/b : 1.747
# Steps : 196480, Gen Loss Total : 26.837, Mel-Spec. Error : 0.281, s/b : 1.753
# Steps : 196485, Gen Loss Total : 28.692, Mel-Spec. Error : 0.294, s/b : 1.848
# Steps : 196490, Gen Loss Total : 28.015, Mel-Spec. Error : 0.292, s/b : 1.753
# Steps : 196495, Gen Loss Total : 27.559, Mel-Spec. Error : 0.297, s/b : 1.745
# Steps : 196500, Gen Loss Total : 26.817, Mel-Spec. Error : 0.292, s/b : 1.870
# Steps : 196505, Gen Loss Total : 26.194, Mel-Spec. Error : 0.291, s/b : 1.848
# Steps : 196510, Gen Loss Total : 27.868, Mel-Spec. Error : 0.292, s/b : 1.748
# Steps : 196515, Gen Loss Total : 27.856, Mel-Spec. Error : 0.307, s/b : 1.746
# Steps : 196520, Gen Loss Total : 28.601, Mel-Spec. Error : 0.301, s/b : 1.746
# Steps : 196525, Gen Loss Total : 29.021, Mel-Spec. Error : 0.296, s/b : 1.817
# Steps : 196530, Gen Loss Total : 27.931, Mel-Spec. Error : 0.294, s/b : 1.749
# Steps : 196535, Gen Loss Total : 26.324, Mel-Spec. Error : 0.282, s/b : 1.742
# Steps : 196540, Gen Loss Total : 26.645, Mel-Spec. Error : 0.291, s/b : 1.745
# Steps : 196545, Gen Loss Total : 26.766, Mel-Spec. Error : 0.290, s/b : 1.843
# Steps : 196550, Gen Loss Total : 26.495, Mel-Spec. Error : 0.286, s/b : 1.751
# Steps : 196555, Gen Loss Total : 28.819, Mel-Spec. Error : 0.294, s/b : 1.750
# Steps : 196560, Gen Loss Total : 27.071, Mel-Spec. Error : 0.302, s/b : 1.755
# Steps : 196565, Gen Loss Total : 26.469, Mel-Spec. Error : 0.282, s/b : 1.810
# Steps : 196570, Gen Loss Total : 26.311, Mel-Spec. Error : 0.296, s/b : 1.737
# Steps : 196575, Gen Loss Total : 25.338, Mel-Spec. Error : 0.286, s/b : 1.742
# Steps : 196580, Gen Loss Total : 26.964, Mel-Spec. Error : 0.301, s/b : 1.757
# Steps : 196585, Gen Loss Total : 26.220, Mel-Spec. Error : 0.295, s/b : 1.828
# Steps : 196590, Gen Loss Total : 27.167, Mel-Spec. Error : 0.285, s/b : 1.750
# Time taken for epoch 324 is 1667 sec
#
# Epoch: 325
# Steps : 196595, Gen Loss Total : 27.349, Mel-Spec. Error : 0.292, s/b : 1.756
# Steps : 196600, Gen Loss Total : 26.310, Mel-Spec. Error : 0.277, s/b : 1.760
# Steps : 196605, Gen Loss Total : 27.560, Mel-Spec. Error : 0.295, s/b : 1.761
# Steps : 196610, Gen Loss Total : 27.931, Mel-Spec. Error : 0.294, s/b : 1.770
# Steps : 196615, Gen Loss Total : 26.380, Mel-Spec. Error : 0.292, s/b : 1.768
# Steps : 196620, Gen Loss Total : 28.650, Mel-Spec. Error : 0.287, s/b : 1.772
# Steps : 196625, Gen Loss Total : 29.428, Mel-Spec. Error : 0.288, s/b : 1.778
# Steps : 196630, Gen Loss Total : 26.551, Mel-Spec. Error : 0.289, s/b : 1.785
# Steps : 196635, Gen Loss Total : 26.153, Mel-Spec. Error : 0.282, s/b : 1.783
# Steps : 196640, Gen Loss Total : 28.457, Mel-Spec. Error : 0.290, s/b : 1.785
# Steps : 196645, Gen Loss Total : 28.743, Mel-Spec. Error : 0.301, s/b : 1.784
# Steps : 196650, Gen Loss Total : 27.265, Mel-Spec. Error : 0.288, s/b : 1.781
# Steps : 196655, Gen Loss Total : 29.806, Mel-Spec. Error : 0.290, s/b : 1.782
# Steps : 196660, Gen Loss Total : 29.315, Mel-Spec. Error : 0.287, s/b : 1.788
# Steps : 196665, Gen Loss Total : 29.116, Mel-Spec. Error : 0.297, s/b : 1.787
# Steps : 196670, Gen Loss Total : 24.502, Mel-Spec. Error : 0.267, s/b : 1.788
# Steps : 196675, Gen Loss Total : 27.742, Mel-Spec. Error : 0.288, s/b : 1.785
# Steps : 196680, Gen Loss Total : 26.983, Mel-Spec. Error : 0.287, s/b : 1.791
# Steps : 196685, Gen Loss Total : 27.534, Mel-Spec. Error : 0.276, s/b : 1.783
# Steps : 196690, Gen Loss Total : 27.132, Mel-Spec. Error : 0.294, s/b : 1.789
# Steps : 196695, Gen Loss Total : 27.192, Mel-Spec. Error : 0.309, s/b : 1.792
# Steps : 196700, Gen Loss Total : 28.071, Mel-Spec. Error : 0.303, s/b : 1.792
# Steps : 196705, Gen Loss Total : 26.307, Mel-Spec. Error : 0.281, s/b : 1.798
# Steps : 196710, Gen Loss Total : 27.130, Mel-Spec. Error : 0.279, s/b : 1.799
# Steps : 196715, Gen Loss Total : 26.925, Mel-Spec. Error : 0.278, s/b : 1.800
# Steps : 196720, Gen Loss Total : 28.098, Mel-Spec. Error : 0.290, s/b : 1.795
# Steps : 196725, Gen Loss Total : 28.101, Mel-Spec. Error : 0.288, s/b : 1.796
# Steps : 196730, Gen Loss Total : 28.927, Mel-Spec. Error : 0.300, s/b : 1.793
# Steps : 196735, Gen Loss Total : 25.800, Mel-Spec. Error : 0.293, s/b : 1.794
# Steps : 196740, Gen Loss Total : 25.800, Mel-Spec. Error : 0.282, s/b : 1.795
# Steps : 196745, Gen Loss Total : 27.716, Mel-Spec. Error : 0.289, s/b : 1.794
# Steps : 196750, Gen Loss Total : 27.985, Mel-Spec. Error : 0.294, s/b : 1.799
# Steps : 196755, Gen Loss Total : 29.706, Mel-Spec. Error : 0.296, s/b : 1.805
# Steps : 196760, Gen Loss Total : 26.527, Mel-Spec. Error : 0.273, s/b : 1.803
# Steps : 196765, Gen Loss Total : 28.454, Mel-Spec. Error : 0.302, s/b : 1.807
# Steps : 196770, Gen Loss Total : 26.277, Mel-Spec. Error : 0.284, s/b : 1.802
# Steps : 196775, Gen Loss Total : 25.829, Mel-Spec. Error : 0.291, s/b : 1.801
# Steps : 196780, Gen Loss Total : 28.761, Mel-Spec. Error : 0.301, s/b : 1.802
# Steps : 196785, Gen Loss Total : 26.964, Mel-Spec. Error : 0.292, s/b : 1.805
# Steps : 196790, Gen Loss Total : 28.410, Mel-Spec. Error : 0.297, s/b : 1.800
# Steps : 196795, Gen Loss Total : 27.824, Mel-Spec. Error : 0.285, s/b : 1.803
# Steps : 196800, Gen Loss Total : 28.115, Mel-Spec. Error : 0.278, s/b : 1.802
# Steps : 196805, Gen Loss Total : 24.455, Mel-Spec. Error : 0.279, s/b : 1.800
# Steps : 196810, Gen Loss Total : 27.028, Mel-Spec. Error : 0.290, s/b : 1.804
# Steps : 196815, Gen Loss Total : 27.188, Mel-Spec. Error : 0.297, s/b : 1.800
# Steps : 196820, Gen Loss Total : 27.614, Mel-Spec. Error : 0.296, s/b : 1.804
# Steps : 196825, Gen Loss Total : 29.758, Mel-Spec. Error : 0.308, s/b : 1.803
# Steps : 196830, Gen Loss Total : 27.808, Mel-Spec. Error : 0.294, s/b : 1.804
# Steps : 196835, Gen Loss Total : 29.122, Mel-Spec. Error : 0.297, s/b : 1.805
# Steps : 196840, Gen Loss Total : 27.854, Mel-Spec. Error : 0.305, s/b : 1.799
# Steps : 196845, Gen Loss Total : 27.655, Mel-Spec. Error : 0.299, s/b : 1.801
# Steps : 196850, Gen Loss Total : 27.346, Mel-Spec. Error : 0.291, s/b : 1.802
# Steps : 196855, Gen Loss Total : 27.562, Mel-Spec. Error : 0.298, s/b : 1.804
# Steps : 196860, Gen Loss Total : 28.270, Mel-Spec. Error : 0.291, s/b : 1.806
# Steps : 196865, Gen Loss Total : 29.624, Mel-Spec. Error : 0.297, s/b : 1.804
# Steps : 196870, Gen Loss Total : 27.814, Mel-Spec. Error : 0.285, s/b : 1.801
# Steps : 196875, Gen Loss Total : 28.365, Mel-Spec. Error : 0.294, s/b : 1.806
# Steps : 196880, Gen Loss Total : 28.037, Mel-Spec. Error : 0.285, s/b : 1.801
# Steps : 196885, Gen Loss Total : 27.228, Mel-Spec. Error : 0.275, s/b : 1.805
# Steps : 196890, Gen Loss Total : 28.616, Mel-Spec. Error : 0.294, s/b : 1.801
# Steps : 196895, Gen Loss Total : 26.739, Mel-Spec. Error : 0.282, s/b : 1.803
# Steps : 196900, Gen Loss Total : 26.361, Mel-Spec. Error : 0.288, s/b : 1.803
# Steps : 196905, Gen Loss Total : 28.739, Mel-Spec. Error : 0.284, s/b : 1.805
# Steps : 196910, Gen Loss Total : 26.348, Mel-Spec. Error : 0.290, s/b : 1.800
# Steps : 196915, Gen Loss Total : 26.770, Mel-Spec. Error : 0.283, s/b : 1.800
# Steps : 196920, Gen Loss Total : 27.842, Mel-Spec. Error : 0.290, s/b : 1.806
# Steps : 196925, Gen Loss Total : 27.568, Mel-Spec. Error : 0.286, s/b : 1.806
# Steps : 196930, Gen Loss Total : 25.886, Mel-Spec. Error : 0.298, s/b : 1.803
# Steps : 196935, Gen Loss Total : 26.283, Mel-Spec. Error : 0.296, s/b : 1.803
# Steps : 196940, Gen Loss Total : 28.264, Mel-Spec. Error : 0.293, s/b : 1.804
# Steps : 196945, Gen Loss Total : 26.759, Mel-Spec. Error : 0.296, s/b : 1.804
# Steps : 196950, Gen Loss Total : 29.046, Mel-Spec. Error : 0.304, s/b : 1.806
# Steps : 196955, Gen Loss Total : 29.358, Mel-Spec. Error : 0.296, s/b : 1.807
# Steps : 196960, Gen Loss Total : 29.924, Mel-Spec. Error : 0.300, s/b : 1.807
# Steps : 196965, Gen Loss Total : 27.198, Mel-Spec. Error : 0.292, s/b : 1.808
# Steps : 196970, Gen Loss Total : 27.265, Mel-Spec. Error : 0.296, s/b : 1.805
# Steps : 196975, Gen Loss Total : 28.647, Mel-Spec. Error : 0.301, s/b : 1.803
# Steps : 196980, Gen Loss Total : 28.481, Mel-Spec. Error : 0.281, s/b : 1.803
# Steps : 196985, Gen Loss Total : 28.633, Mel-Spec. Error : 0.291, s/b : 1.807
# Steps : 196990, Gen Loss Total : 28.298, Mel-Spec. Error : 0.295, s/b : 1.807
# Steps : 196995, Gen Loss Total : 27.452, Mel-Spec. Error : 0.292, s/b : 1.804
# Steps : 197000, Gen Loss Total : 28.107, Mel-Spec. Error : 0.295, s/b : 2.093
# val err tot:  0.27006411159038546
# Steps : 197005, Gen Loss Total : 28.738, Mel-Spec. Error : 0.296, s/b : 1.725
# Steps : 197010, Gen Loss Total : 28.397, Mel-Spec. Error : 0.299, s/b : 1.737
# Steps : 197015, Gen Loss Total : 28.024, Mel-Spec. Error : 0.284, s/b : 1.742
# Steps : 197020, Gen Loss Total : 26.523, Mel-Spec. Error : 0.309, s/b : 1.745
# Steps : 197025, Gen Loss Total : 27.364, Mel-Spec. Error : 0.289, s/b : 1.741
# Steps : 197030, Gen Loss Total : 28.348, Mel-Spec. Error : 0.297, s/b : 1.754
# Steps : 197035, Gen Loss Total : 27.012, Mel-Spec. Error : 0.291, s/b : 1.752
# Steps : 197040, Gen Loss Total : 29.922, Mel-Spec. Error : 0.308, s/b : 1.761
# Steps : 197045, Gen Loss Total : 29.180, Mel-Spec. Error : 0.287, s/b : 1.766
# Steps : 197050, Gen Loss Total : 28.021, Mel-Spec. Error : 0.281, s/b : 1.767
# Steps : 197055, Gen Loss Total : 25.830, Mel-Spec. Error : 0.288, s/b : 1.759
# Steps : 197060, Gen Loss Total : 26.202, Mel-Spec. Error : 0.293, s/b : 1.769
# Steps : 197065, Gen Loss Total : 28.050, Mel-Spec. Error : 0.291, s/b : 1.779
# Steps : 197070, Gen Loss Total : 27.801, Mel-Spec. Error : 0.280, s/b : 1.779
# Steps : 197075, Gen Loss Total : 29.466, Mel-Spec. Error : 0.293, s/b : 1.784
# Steps : 197080, Gen Loss Total : 27.029, Mel-Spec. Error : 0.284, s/b : 1.774
# Steps : 197085, Gen Loss Total : 28.423, Mel-Spec. Error : 0.298, s/b : 1.778
# Steps : 197090, Gen Loss Total : 27.762, Mel-Spec. Error : 0.291, s/b : 1.781
# Steps : 197095, Gen Loss Total : 26.607, Mel-Spec. Error : 0.293, s/b : 1.781
# Steps : 197100, Gen Loss Total : 29.476, Mel-Spec. Error : 0.304, s/b : 1.785
# Steps : 197105, Gen Loss Total : 26.467, Mel-Spec. Error : 0.295, s/b : 1.783
# Steps : 197110, Gen Loss Total : 26.428, Mel-Spec. Error : 0.290, s/b : 1.785
# Steps : 197115, Gen Loss Total : 26.911, Mel-Spec. Error : 0.310, s/b : 1.786
# Steps : 197120, Gen Loss Total : 28.448, Mel-Spec. Error : 0.307, s/b : 1.795
# Steps : 197125, Gen Loss Total : 28.080, Mel-Spec. Error : 0.299, s/b : 1.793
# Steps : 197130, Gen Loss Total : 27.703, Mel-Spec. Error : 0.305, s/b : 1.789
# Steps : 197135, Gen Loss Total : 26.187, Mel-Spec. Error : 0.288, s/b : 1.793
# Steps : 197140, Gen Loss Total : 27.794, Mel-Spec. Error : 0.293, s/b : 1.792
# Steps : 197145, Gen Loss Total : 29.338, Mel-Spec. Error : 0.304, s/b : 1.793
# Steps : 197150, Gen Loss Total : 26.099, Mel-Spec. Error : 0.288, s/b : 1.796
# Steps : 197155, Gen Loss Total : 28.941, Mel-Spec. Error : 0.299, s/b : 1.789
# Steps : 197160, Gen Loss Total : 26.860, Mel-Spec. Error : 0.283, s/b : 1.796
# Steps : 197165, Gen Loss Total : 28.449, Mel-Spec. Error : 0.304, s/b : 1.797
# Steps : 197170, Gen Loss Total : 27.502, Mel-Spec. Error : 0.294, s/b : 1.796
# Steps : 197175, Gen Loss Total : 27.122, Mel-Spec. Error : 0.294, s/b : 1.796
# Steps : 197180, Gen Loss Total : 28.474, Mel-Spec. Error : 0.300, s/b : 1.793
# Steps : 197185, Gen Loss Total : 26.499, Mel-Spec. Error : 0.297, s/b : 1.798
# Time taken for epoch 325 is 1399 sec
#
# Epoch: 326
# Steps : 197190, Gen Loss Total : 26.181, Mel-Spec. Error : 0.282, s/b : 1.796
# Steps : 197195, Gen Loss Total : 28.795, Mel-Spec. Error : 0.298, s/b : 1.794
# Steps : 197200, Gen Loss Total : 27.637, Mel-Spec. Error : 0.308, s/b : 1.798
# Steps : 197205, Gen Loss Total : 25.722, Mel-Spec. Error : 0.283, s/b : 1.794
# Steps : 197210, Gen Loss Total : 26.757, Mel-Spec. Error : 0.294, s/b : 1.791
# Steps : 197215, Gen Loss Total : 26.408, Mel-Spec. Error : 0.277, s/b : 1.794
# Steps : 197220, Gen Loss Total : 29.020, Mel-Spec. Error : 0.295, s/b : 1.795
# Steps : 197225, Gen Loss Total : 27.648, Mel-Spec. Error : 0.285, s/b : 1.793
# Steps : 197230, Gen Loss Total : 27.460, Mel-Spec. Error : 0.283, s/b : 1.791
# Steps : 197235, Gen Loss Total : 27.326, Mel-Spec. Error : 0.297, s/b : 1.796
# Steps : 197240, Gen Loss Total : 27.286, Mel-Spec. Error : 0.284, s/b : 1.795
# Steps : 197245, Gen Loss Total : 28.939, Mel-Spec. Error : 0.295, s/b : 1.797
# Steps : 197250, Gen Loss Total : 24.443, Mel-Spec. Error : 0.265, s/b : 1.796
# Steps : 197255, Gen Loss Total : 26.289, Mel-Spec. Error : 0.282, s/b : 1.795
# Steps : 197260, Gen Loss Total : 28.211, Mel-Spec. Error : 0.291, s/b : 1.795
# Steps : 197265, Gen Loss Total : 27.915, Mel-Spec. Error : 0.303, s/b : 1.799
# Steps : 197270, Gen Loss Total : 26.305, Mel-Spec. Error : 0.285, s/b : 1.794
# Steps : 197275, Gen Loss Total : 25.570, Mel-Spec. Error : 0.287, s/b : 1.799
# Steps : 197280, Gen Loss Total : 26.613, Mel-Spec. Error : 0.280, s/b : 1.799
# Steps : 197285, Gen Loss Total : 30.018, Mel-Spec. Error : 0.294, s/b : 1.795
# Steps : 197290, Gen Loss Total : 26.369, Mel-Spec. Error : 0.287, s/b : 1.802
# Steps : 197295, Gen Loss Total : 27.484, Mel-Spec. Error : 0.294, s/b : 1.794
# Steps : 197300, Gen Loss Total : 28.635, Mel-Spec. Error : 0.294, s/b : 1.800
# Steps : 197305, Gen Loss Total : 29.751, Mel-Spec. Error : 0.305, s/b : 1.800
# Steps : 197310, Gen Loss Total : 27.472, Mel-Spec. Error : 0.291, s/b : 1.800
# Steps : 197315, Gen Loss Total : 28.180, Mel-Spec. Error : 0.281, s/b : 1.797
# Steps : 197320, Gen Loss Total : 25.427, Mel-Spec. Error : 0.266, s/b : 1.795
# Steps : 197325, Gen Loss Total : 27.719, Mel-Spec. Error : 0.293, s/b : 1.797
# Steps : 197330, Gen Loss Total : 27.989, Mel-Spec. Error : 0.284, s/b : 1.794
# Steps : 197335, Gen Loss Total : 29.028, Mel-Spec. Error : 0.300, s/b : 1.795
# Steps : 197340, Gen Loss Total : 28.461, Mel-Spec. Error : 0.277, s/b : 1.794
# Steps : 197345, Gen Loss Total : 28.119, Mel-Spec. Error : 0.290, s/b : 1.793
# Steps : 197350, Gen Loss Total : 29.219, Mel-Spec. Error : 0.286, s/b : 1.791
# Steps : 197355, Gen Loss Total : 28.209, Mel-Spec. Error : 0.306, s/b : 1.794
# Steps : 197360, Gen Loss Total : 28.120, Mel-Spec. Error : 0.278, s/b : 1.795
# Steps : 197365, Gen Loss Total : 29.889, Mel-Spec. Error : 0.298, s/b : 1.798
# Steps : 197370, Gen Loss Total : 29.003, Mel-Spec. Error : 0.289, s/b : 1.805
# Steps : 197375, Gen Loss Total : 27.173, Mel-Spec. Error : 0.283, s/b : 1.805
# Steps : 197380, Gen Loss Total : 26.268, Mel-Spec. Error : 0.276, s/b : 1.806
# Steps : 197385, Gen Loss Total : 28.931, Mel-Spec. Error : 0.279, s/b : 1.802
# Steps : 197390, Gen Loss Total : 26.141, Mel-Spec. Error : 0.286, s/b : 1.808
# Steps : 197395, Gen Loss Total : 27.350, Mel-Spec. Error : 0.287, s/b : 1.801
# Steps : 197400, Gen Loss Total : 28.099, Mel-Spec. Error : 0.288, s/b : 1.802
# Steps : 197405, Gen Loss Total : 24.915, Mel-Spec. Error : 0.276, s/b : 1.800
# Steps : 197410, Gen Loss Total : 28.184, Mel-Spec. Error : 0.287, s/b : 1.798
# Steps : 197415, Gen Loss Total : 28.679, Mel-Spec. Error : 0.284, s/b : 1.796
# Steps : 197420, Gen Loss Total : 24.906, Mel-Spec. Error : 0.281, s/b : 1.799
# Steps : 197425, Gen Loss Total : 28.302, Mel-Spec. Error : 0.286, s/b : 1.799
# Steps : 197430, Gen Loss Total : 25.663, Mel-Spec. Error : 0.277, s/b : 1.800
# Steps : 197435, Gen Loss Total : 28.172, Mel-Spec. Error : 0.300, s/b : 1.797
# Steps : 197440, Gen Loss Total : 26.384, Mel-Spec. Error : 0.279, s/b : 1.799
# Steps : 197445, Gen Loss Total : 26.794, Mel-Spec. Error : 0.285, s/b : 1.801
# Steps : 197450, Gen Loss Total : 28.056, Mel-Spec. Error : 0.305, s/b : 1.797
# Steps : 197455, Gen Loss Total : 26.674, Mel-Spec. Error : 0.289, s/b : 1.803
# Steps : 197460, Gen Loss Total : 29.369, Mel-Spec. Error : 0.308, s/b : 1.801
# Steps : 197465, Gen Loss Total : 28.126, Mel-Spec. Error : 0.309, s/b : 1.800
# Steps : 197470, Gen Loss Total : 27.999, Mel-Spec. Error : 0.292, s/b : 1.797
# Steps : 197475, Gen Loss Total : 26.326, Mel-Spec. Error : 0.284, s/b : 1.802
# Steps : 197480, Gen Loss Total : 28.022, Mel-Spec. Error : 0.299, s/b : 1.800
# Steps : 197485, Gen Loss Total : 28.261, Mel-Spec. Error : 0.297, s/b : 1.799
# Steps : 197490, Gen Loss Total : 29.420, Mel-Spec. Error : 0.287, s/b : 1.799
# Steps : 197495, Gen Loss Total : 27.723, Mel-Spec. Error : 0.287, s/b : 1.801
# Steps : 197500, Gen Loss Total : 25.936, Mel-Spec. Error : 0.270, s/b : 1.913
# Steps : 197505, Gen Loss Total : 25.768, Mel-Spec. Error : 0.276, s/b : 1.805
# Steps : 197510, Gen Loss Total : 28.700, Mel-Spec. Error : 0.296, s/b : 1.799
# Steps : 197515, Gen Loss Total : 27.462, Mel-Spec. Error : 0.290, s/b : 1.797
# Steps : 197520, Gen Loss Total : 27.486, Mel-Spec. Error : 0.294, s/b : 1.801
# Steps : 197525, Gen Loss Total : 27.035, Mel-Spec. Error : 0.277, s/b : 1.798
# Steps : 197530, Gen Loss Total : 27.603, Mel-Spec. Error : 0.296, s/b : 1.801
# Steps : 197535, Gen Loss Total : 27.752, Mel-Spec. Error : 0.280, s/b : 1.801
# Steps : 197540, Gen Loss Total : 26.876, Mel-Spec. Error : 0.295, s/b : 1.804
# Steps : 197545, Gen Loss Total : 25.667, Mel-Spec. Error : 0.262, s/b : 1.799
# Steps : 197550, Gen Loss Total : 28.236, Mel-Spec. Error : 0.293, s/b : 1.801
# Steps : 197555, Gen Loss Total : 27.297, Mel-Spec. Error : 0.286, s/b : 1.798
# Steps : 197560, Gen Loss Total : 27.236, Mel-Spec. Error : 0.297, s/b : 1.801
# Steps : 197565, Gen Loss Total : 27.030, Mel-Spec. Error : 0.286, s/b : 1.798
# Steps : 197570, Gen Loss Total : 28.329, Mel-Spec. Error : 0.302, s/b : 1.805
# Steps : 197575, Gen Loss Total : 27.652, Mel-Spec. Error : 0.309, s/b : 1.797
# Steps : 197580, Gen Loss Total : 27.391, Mel-Spec. Error : 0.291, s/b : 1.800
# Steps : 197585, Gen Loss Total : 27.785, Mel-Spec. Error : 0.282, s/b : 1.799
# Steps : 197590, Gen Loss Total : 27.522, Mel-Spec. Error : 0.303, s/b : 1.798
# Steps : 197595, Gen Loss Total : 27.455, Mel-Spec. Error : 0.299, s/b : 1.798
# Steps : 197600, Gen Loss Total : 30.315, Mel-Spec. Error : 0.298, s/b : 1.805
# Steps : 197605, Gen Loss Total : 26.994, Mel-Spec. Error : 0.306, s/b : 1.798
# Steps : 197610, Gen Loss Total : 29.624, Mel-Spec. Error : 0.293, s/b : 1.801
# Steps : 197615, Gen Loss Total : 30.088, Mel-Spec. Error : 0.288, s/b : 1.798
# Steps : 197620, Gen Loss Total : 26.620, Mel-Spec. Error : 0.275, s/b : 1.801
# Steps : 197625, Gen Loss Total : 27.901, Mel-Spec. Error : 0.276, s/b : 1.800
# Steps : 197630, Gen Loss Total : 29.777, Mel-Spec. Error : 0.285, s/b : 1.802
# Steps : 197635, Gen Loss Total : 28.611, Mel-Spec. Error : 0.284, s/b : 1.804
# Steps : 197640, Gen Loss Total : 28.510, Mel-Spec. Error : 0.288, s/b : 1.804
# Steps : 197645, Gen Loss Total : 27.673, Mel-Spec. Error : 0.278, s/b : 1.802
# Steps : 197650, Gen Loss Total : 27.324, Mel-Spec. Error : 0.294, s/b : 1.801
# Steps : 197655, Gen Loss Total : 27.955, Mel-Spec. Error : 0.291, s/b : 1.803
# Steps : 197660, Gen Loss Total : 26.514, Mel-Spec. Error : 0.281, s/b : 1.801
# Steps : 197665, Gen Loss Total : 25.973, Mel-Spec. Error : 0.286, s/b : 1.801
# Steps : 197670, Gen Loss Total : 27.680, Mel-Spec. Error : 0.295, s/b : 1.801
# Steps : 197675, Gen Loss Total : 28.679, Mel-Spec. Error : 0.296, s/b : 1.803
# Steps : 197680, Gen Loss Total : 28.894, Mel-Spec. Error : 0.283, s/b : 1.798
# Steps : 197685, Gen Loss Total : 28.872, Mel-Spec. Error : 0.285, s/b : 1.804
# Steps : 197690, Gen Loss Total : 28.430, Mel-Spec. Error : 0.291, s/b : 1.806
# Steps : 197695, Gen Loss Total : 24.334, Mel-Spec. Error : 0.282, s/b : 1.805
# Steps : 197700, Gen Loss Total : 26.551, Mel-Spec. Error : 0.296, s/b : 1.806
# Steps : 197705, Gen Loss Total : 26.534, Mel-Spec. Error : 0.300, s/b : 1.798
# Steps : 197710, Gen Loss Total : 27.307, Mel-Spec. Error : 0.298, s/b : 1.801
# Steps : 197715, Gen Loss Total : 26.438, Mel-Spec. Error : 0.276, s/b : 1.807
# Steps : 197720, Gen Loss Total : 27.905, Mel-Spec. Error : 0.294, s/b : 1.805
# Steps : 197725, Gen Loss Total : 27.706, Mel-Spec. Error : 0.292, s/b : 1.802
# Steps : 197730, Gen Loss Total : 27.967, Mel-Spec. Error : 0.278, s/b : 1.804
# Steps : 197735, Gen Loss Total : 27.892, Mel-Spec. Error : 0.286, s/b : 1.799
# Steps : 197740, Gen Loss Total : 26.869, Mel-Spec. Error : 0.297, s/b : 1.800
# Steps : 197745, Gen Loss Total : 28.004, Mel-Spec. Error : 0.298, s/b : 1.802
# Steps : 197750, Gen Loss Total : 27.730, Mel-Spec. Error : 0.293, s/b : 1.800
# Steps : 197755, Gen Loss Total : 27.651, Mel-Spec. Error : 0.283, s/b : 1.800
# Steps : 197760, Gen Loss Total : 25.641, Mel-Spec. Error : 0.286, s/b : 1.799
# Steps : 197765, Gen Loss Total : 26.258, Mel-Spec. Error : 0.269, s/b : 1.806
# Steps : 197770, Gen Loss Total : 29.748, Mel-Spec. Error : 0.301, s/b : 1.802
# Steps : 197775, Gen Loss Total : 29.414, Mel-Spec. Error : 0.308, s/b : 1.800
# Time taken for epoch 326 is 1068 sec
#
# Epoch: 327
# Steps : 197780, Gen Loss Total : 26.223, Mel-Spec. Error : 0.279, s/b : 1.818
# Steps : 197785, Gen Loss Total : 29.210, Mel-Spec. Error : 0.303, s/b : 1.806
# Steps : 197790, Gen Loss Total : 26.279, Mel-Spec. Error : 0.290, s/b : 1.807
# Steps : 197795, Gen Loss Total : 24.645, Mel-Spec. Error : 0.276, s/b : 1.802
# Steps : 197800, Gen Loss Total : 28.329, Mel-Spec. Error : 0.298, s/b : 1.799
# Steps : 197805, Gen Loss Total : 28.560, Mel-Spec. Error : 0.293, s/b : 1.802
# Steps : 197810, Gen Loss Total : 26.991, Mel-Spec. Error : 0.274, s/b : 1.805
# Steps : 197815, Gen Loss Total : 27.097, Mel-Spec. Error : 0.291, s/b : 1.807
# Steps : 197820, Gen Loss Total : 26.813, Mel-Spec. Error : 0.298, s/b : 1.805
# Steps : 197825, Gen Loss Total : 29.379, Mel-Spec. Error : 0.308, s/b : 1.801
# Steps : 197830, Gen Loss Total : 27.646, Mel-Spec. Error : 0.299, s/b : 1.804
# Steps : 197835, Gen Loss Total : 28.274, Mel-Spec. Error : 0.292, s/b : 1.805
# Steps : 197840, Gen Loss Total : 27.056, Mel-Spec. Error : 0.277, s/b : 1.802
# Steps : 197845, Gen Loss Total : 27.426, Mel-Spec. Error : 0.298, s/b : 1.803
# Steps : 197850, Gen Loss Total : 28.543, Mel-Spec. Error : 0.294, s/b : 1.805
# Steps : 197855, Gen Loss Total : 26.648, Mel-Spec. Error : 0.298, s/b : 1.805
# Steps : 197860, Gen Loss Total : 29.892, Mel-Spec. Error : 0.300, s/b : 1.802
# Steps : 197865, Gen Loss Total : 28.320, Mel-Spec. Error : 0.280, s/b : 1.806
# Steps : 197870, Gen Loss Total : 28.751, Mel-Spec. Error : 0.292, s/b : 1.802
# Steps : 197875, Gen Loss Total : 27.602, Mel-Spec. Error : 0.300, s/b : 1.801
# Steps : 197880, Gen Loss Total : 27.795, Mel-Spec. Error : 0.296, s/b : 1.802
# Steps : 197885, Gen Loss Total : 31.239, Mel-Spec. Error : 0.301, s/b : 1.801
# Steps : 197890, Gen Loss Total : 29.066, Mel-Spec. Error : 0.298, s/b : 1.798
# Steps : 197895, Gen Loss Total : 27.081, Mel-Spec. Error : 0.289, s/b : 1.801
# Steps : 197900, Gen Loss Total : 28.242, Mel-Spec. Error : 0.289, s/b : 1.803
# Steps : 197905, Gen Loss Total : 28.820, Mel-Spec. Error : 0.281, s/b : 1.801
# Steps : 197910, Gen Loss Total : 29.211, Mel-Spec. Error : 0.290, s/b : 1.809
# Steps : 197915, Gen Loss Total : 27.894, Mel-Spec. Error : 0.290, s/b : 1.805
# Steps : 197920, Gen Loss Total : 28.568, Mel-Spec. Error : 0.288, s/b : 1.802
# Steps : 197925, Gen Loss Total : 28.763, Mel-Spec. Error : 0.293, s/b : 1.807
# Steps : 197930, Gen Loss Total : 28.895, Mel-Spec. Error : 0.283, s/b : 1.804
# Steps : 197935, Gen Loss Total : 26.657, Mel-Spec. Error : 0.290, s/b : 1.810
# Steps : 197940, Gen Loss Total : 28.569, Mel-Spec. Error : 0.297, s/b : 1.807
# Steps : 197945, Gen Loss Total : 26.420, Mel-Spec. Error : 0.286, s/b : 1.805
# Steps : 197950, Gen Loss Total : 25.499, Mel-Spec. Error : 0.283, s/b : 1.802
# Steps : 197955, Gen Loss Total : 27.858, Mel-Spec. Error : 0.284, s/b : 1.805
# Steps : 197960, Gen Loss Total : 25.309, Mel-Spec. Error : 0.274, s/b : 1.803
# Steps : 197965, Gen Loss Total : 28.724, Mel-Spec. Error : 0.294, s/b : 1.808
# Steps : 197970, Gen Loss Total : 27.666, Mel-Spec. Error : 0.290, s/b : 1.803
# Steps : 197975, Gen Loss Total : 28.237, Mel-Spec. Error : 0.289, s/b : 1.801
# Steps : 197980, Gen Loss Total : 26.930, Mel-Spec. Error : 0.285, s/b : 1.803
# Steps : 197985, Gen Loss Total : 27.554, Mel-Spec. Error : 0.298, s/b : 1.804
# Steps : 197990, Gen Loss Total : 27.977, Mel-Spec. Error : 0.297, s/b : 1.799
# Steps : 197995, Gen Loss Total : 27.932, Mel-Spec. Error : 0.297, s/b : 1.803
# Steps : 198000, Gen Loss Total : 25.625, Mel-Spec. Error : 0.288, s/b : 2.096
# val err tot:  0.26689984354376795
# Steps : 198005, Gen Loss Total : 27.215, Mel-Spec. Error : 0.291, s/b : 1.797
# Steps : 198010, Gen Loss Total : 27.886, Mel-Spec. Error : 0.296, s/b : 1.805
# Steps : 198015, Gen Loss Total : 27.335, Mel-Spec. Error : 0.293, s/b : 1.807
# Steps : 198020, Gen Loss Total : 25.957, Mel-Spec. Error : 0.278, s/b : 1.798
# Steps : 198025, Gen Loss Total : 27.822, Mel-Spec. Error : 0.284, s/b : 1.809
# Steps : 198030, Gen Loss Total : 24.840, Mel-Spec. Error : 0.268, s/b : 1.801
# Steps : 198035, Gen Loss Total : 27.835, Mel-Spec. Error : 0.290, s/b : 1.806
# Steps : 198040, Gen Loss Total : 22.823, Mel-Spec. Error : 0.253, s/b : 1.803
# Steps : 198045, Gen Loss Total : 26.071, Mel-Spec. Error : 0.284, s/b : 1.798
# Steps : 198050, Gen Loss Total : 29.726, Mel-Spec. Error : 0.305, s/b : 1.806
# Steps : 198055, Gen Loss Total : 29.166, Mel-Spec. Error : 0.311, s/b : 1.805
# Steps : 198060, Gen Loss Total : 26.972, Mel-Spec. Error : 0.297, s/b : 1.796
# Steps : 198065, Gen Loss Total : 29.339, Mel-Spec. Error : 0.301, s/b : 1.805
# Steps : 198070, Gen Loss Total : 29.977, Mel-Spec. Error : 0.302, s/b : 1.801
# Steps : 198075, Gen Loss Total : 27.464, Mel-Spec. Error : 0.302, s/b : 1.802
# Steps : 198080, Gen Loss Total : 29.704, Mel-Spec. Error : 0.309, s/b : 1.807
# Steps : 198085, Gen Loss Total : 29.654, Mel-Spec. Error : 0.303, s/b : 1.803
# Steps : 198090, Gen Loss Total : 28.029, Mel-Spec. Error : 0.293, s/b : 1.804
# Steps : 198095, Gen Loss Total : 28.181, Mel-Spec. Error : 0.292, s/b : 1.804
# Steps : 198100, Gen Loss Total : 29.219, Mel-Spec. Error : 0.305, s/b : 1.801
# Steps : 198105, Gen Loss Total : 27.870, Mel-Spec. Error : 0.291, s/b : 1.801
# Steps : 198110, Gen Loss Total : 28.521, Mel-Spec. Error : 0.278, s/b : 1.804
# Steps : 198115, Gen Loss Total : 27.633, Mel-Spec. Error : 0.278, s/b : 1.799
# Steps : 198120, Gen Loss Total : 26.374, Mel-Spec. Error : 0.287, s/b : 1.803
# Steps : 198125, Gen Loss Total : 27.699, Mel-Spec. Error : 0.300, s/b : 1.803
# Steps : 198130, Gen Loss Total : 28.560, Mel-Spec. Error : 0.288, s/b : 1.803
# Steps : 198135, Gen Loss Total : 25.692, Mel-Spec. Error : 0.282, s/b : 1.800
# Steps : 198140, Gen Loss Total : 26.342, Mel-Spec. Error : 0.284, s/b : 1.801
# Steps : 198145, Gen Loss Total : 27.122, Mel-Spec. Error : 0.289, s/b : 1.804
# Steps : 198150, Gen Loss Total : 28.752, Mel-Spec. Error : 0.302, s/b : 1.804
# Steps : 198155, Gen Loss Total : 29.087, Mel-Spec. Error : 0.291, s/b : 1.804
# Steps : 198160, Gen Loss Total : 27.783, Mel-Spec. Error : 0.299, s/b : 1.805
# Steps : 198165, Gen Loss Total : 27.160, Mel-Spec. Error : 0.303, s/b : 1.800
# Steps : 198170, Gen Loss Total : 28.623, Mel-Spec. Error : 0.304, s/b : 1.801
# Steps : 198175, Gen Loss Total : 26.327, Mel-Spec. Error : 0.290, s/b : 1.806
# Steps : 198180, Gen Loss Total : 27.813, Mel-Spec. Error : 0.290, s/b : 1.801
# Steps : 198185, Gen Loss Total : 28.512, Mel-Spec. Error : 0.294, s/b : 1.801
# Steps : 198190, Gen Loss Total : 25.467, Mel-Spec. Error : 0.291, s/b : 1.804
# Steps : 198195, Gen Loss Total : 26.559, Mel-Spec. Error : 0.292, s/b : 1.803
# Steps : 198200, Gen Loss Total : 26.186, Mel-Spec. Error : 0.291, s/b : 1.804
# Steps : 198205, Gen Loss Total : 27.921, Mel-Spec. Error : 0.297, s/b : 1.802
# Steps : 198210, Gen Loss Total : 27.605, Mel-Spec. Error : 0.299, s/b : 1.803
# Steps : 198215, Gen Loss Total : 28.607, Mel-Spec. Error : 0.290, s/b : 1.805
# Steps : 198220, Gen Loss Total : 26.959, Mel-Spec. Error : 0.284, s/b : 1.801
# Steps : 198225, Gen Loss Total : 25.310, Mel-Spec. Error : 0.286, s/b : 1.805
# Steps : 198230, Gen Loss Total : 29.329, Mel-Spec. Error : 0.295, s/b : 1.804
# Steps : 198235, Gen Loss Total : 27.495, Mel-Spec. Error : 0.272, s/b : 1.804
# Steps : 198240, Gen Loss Total : 25.415, Mel-Spec. Error : 0.282, s/b : 1.800
# Steps : 198245, Gen Loss Total : 28.322, Mel-Spec. Error : 0.287, s/b : 1.803
# Steps : 198250, Gen Loss Total : 28.244, Mel-Spec. Error : 0.282, s/b : 1.805
# Steps : 198255, Gen Loss Total : 26.612, Mel-Spec. Error : 0.299, s/b : 1.810
# Steps : 198260, Gen Loss Total : 27.663, Mel-Spec. Error : 0.293, s/b : 1.805
# Steps : 198265, Gen Loss Total : 29.493, Mel-Spec. Error : 0.283, s/b : 1.803
# Steps : 198270, Gen Loss Total : 28.470, Mel-Spec. Error : 0.280, s/b : 1.804
# Steps : 198275, Gen Loss Total : 27.343, Mel-Spec. Error : 0.274, s/b : 1.804
# Steps : 198280, Gen Loss Total : 27.328, Mel-Spec. Error : 0.272, s/b : 1.802
# Steps : 198285, Gen Loss Total : 26.746, Mel-Spec. Error : 0.283, s/b : 1.803
# Steps : 198290, Gen Loss Total : 26.854, Mel-Spec. Error : 0.282, s/b : 1.805
# Steps : 198295, Gen Loss Total : 25.192, Mel-Spec. Error : 0.287, s/b : 1.801
# Steps : 198300, Gen Loss Total : 28.011, Mel-Spec. Error : 0.298, s/b : 1.803
# Steps : 198305, Gen Loss Total : 27.408, Mel-Spec. Error : 0.290, s/b : 1.802
# Steps : 198310, Gen Loss Total : 26.903, Mel-Spec. Error : 0.294, s/b : 1.806
# Steps : 198315, Gen Loss Total : 27.665, Mel-Spec. Error : 0.296, s/b : 1.799
# Steps : 198320, Gen Loss Total : 27.995, Mel-Spec. Error : 0.291, s/b : 1.802
# Steps : 198325, Gen Loss Total : 26.675, Mel-Spec. Error : 0.281, s/b : 1.803
# Steps : 198330, Gen Loss Total : 26.571, Mel-Spec. Error : 0.279, s/b : 1.802
# Steps : 198335, Gen Loss Total : 26.109, Mel-Spec. Error : 0.288, s/b : 1.803
# Steps : 198340, Gen Loss Total : 26.818, Mel-Spec. Error : 0.297, s/b : 1.805
# Steps : 198345, Gen Loss Total : 29.163, Mel-Spec. Error : 0.289, s/b : 1.805
# Steps : 198350, Gen Loss Total : 27.370, Mel-Spec. Error : 0.285, s/b : 1.805
# Steps : 198355, Gen Loss Total : 26.598, Mel-Spec. Error : 0.282, s/b : 1.803
# Steps : 198360, Gen Loss Total : 30.585, Mel-Spec. Error : 0.297, s/b : 1.806
# Steps : 198365, Gen Loss Total : 29.028, Mel-Spec. Error : 0.285, s/b : 1.800
# Steps : 198370, Gen Loss Total : 27.237, Mel-Spec. Error : 0.289, s/b : 1.802
# Time taken for epoch 327 is 1117 sec
#
# Epoch: 328
# Steps : 198375, Gen Loss Total : 28.196, Mel-Spec. Error : 0.285, s/b : 1.803
# Steps : 198380, Gen Loss Total : 27.116, Mel-Spec. Error : 0.273, s/b : 1.805
# Steps : 198385, Gen Loss Total : 24.665, Mel-Spec. Error : 0.270, s/b : 1.800
# Steps : 198390, Gen Loss Total : 28.188, Mel-Spec. Error : 0.288, s/b : 1.803
# Steps : 198395, Gen Loss Total : 26.341, Mel-Spec. Error : 0.260, s/b : 1.799
# Steps : 198400, Gen Loss Total : 28.021, Mel-Spec. Error : 0.295, s/b : 1.801
# Steps : 198405, Gen Loss Total : 27.110, Mel-Spec. Error : 0.290, s/b : 1.804
# Steps : 198410, Gen Loss Total : 30.960, Mel-Spec. Error : 0.293, s/b : 1.802
# Steps : 198415, Gen Loss Total : 27.844, Mel-Spec. Error : 0.282, s/b : 1.805
# Steps : 198420, Gen Loss Total : 26.784, Mel-Spec. Error : 0.276, s/b : 1.804
# Steps : 198425, Gen Loss Total : 28.111, Mel-Spec. Error : 0.299, s/b : 1.805
# Steps : 198430, Gen Loss Total : 28.123, Mel-Spec. Error : 0.288, s/b : 1.804
# Steps : 198435, Gen Loss Total : 25.002, Mel-Spec. Error : 0.285, s/b : 1.805
# Steps : 198440, Gen Loss Total : 27.097, Mel-Spec. Error : 0.302, s/b : 1.804
# Steps : 198445, Gen Loss Total : 27.839, Mel-Spec. Error : 0.286, s/b : 1.803
# Steps : 198450, Gen Loss Total : 28.443, Mel-Spec. Error : 0.302, s/b : 1.802
# Steps : 198455, Gen Loss Total : 27.542, Mel-Spec. Error : 0.297, s/b : 1.803
# Steps : 198460, Gen Loss Total : 26.688, Mel-Spec. Error : 0.287, s/b : 1.804
# Steps : 198465, Gen Loss Total : 25.886, Mel-Spec. Error : 0.279, s/b : 1.801
# Steps : 198470, Gen Loss Total : 28.252, Mel-Spec. Error : 0.299, s/b : 1.799
# Steps : 198475, Gen Loss Total : 26.322, Mel-Spec. Error : 0.280, s/b : 1.804
# Steps : 198480, Gen Loss Total : 24.971, Mel-Spec. Error : 0.284, s/b : 1.806
# Steps : 198485, Gen Loss Total : 25.819, Mel-Spec. Error : 0.277, s/b : 1.801
# Steps : 198490, Gen Loss Total : 27.267, Mel-Spec. Error : 0.298, s/b : 1.800
# Steps : 198495, Gen Loss Total : 28.286, Mel-Spec. Error : 0.296, s/b : 1.804
# Steps : 198500, Gen Loss Total : 27.809, Mel-Spec. Error : 0.280, s/b : 1.920
# Steps : 198505, Gen Loss Total : 29.018, Mel-Spec. Error : 0.280, s/b : 1.804
# Steps : 198510, Gen Loss Total : 27.596, Mel-Spec. Error : 0.296, s/b : 1.805
# Steps : 198515, Gen Loss Total : 26.142, Mel-Spec. Error : 0.294, s/b : 1.803
# Steps : 198520, Gen Loss Total : 28.219, Mel-Spec. Error : 0.300, s/b : 1.800
# Steps : 198525, Gen Loss Total : 28.457, Mel-Spec. Error : 0.296, s/b : 1.807
# Steps : 198530, Gen Loss Total : 29.417, Mel-Spec. Error : 0.298, s/b : 1.806
# Steps : 198535, Gen Loss Total : 27.144, Mel-Spec. Error : 0.297, s/b : 1.807
# Steps : 198540, Gen Loss Total : 27.907, Mel-Spec. Error : 0.300, s/b : 1.804
# Steps : 198545, Gen Loss Total : 27.345, Mel-Spec. Error : 0.291, s/b : 1.803
# Steps : 198550, Gen Loss Total : 29.384, Mel-Spec. Error : 0.292, s/b : 1.802
# Steps : 198555, Gen Loss Total : 27.997, Mel-Spec. Error : 0.295, s/b : 1.808
# Steps : 198560, Gen Loss Total : 27.368, Mel-Spec. Error : 0.298, s/b : 1.800
# Steps : 198565, Gen Loss Total : 27.495, Mel-Spec. Error : 0.287, s/b : 1.803
# Steps : 198570, Gen Loss Total : 28.209, Mel-Spec. Error : 0.290, s/b : 1.804
# ...
# Steps : 199255, Gen Loss Total : 25.832, Mel-Spec. Error : 0.290, s/b : 1.807
# Steps : 199260, Gen Loss Total : 28.412, Mel-Spec. Error : 0.288, s/b : 1.802
# Steps : 199265, Gen Loss Total : 27.796, Mel-Spec. Error : 0.291, s/b : 1.802
# Steps : 199270, Gen Loss Total : 27.969, Mel-Spec. Error : 0.291, s/b : 1.801
# Steps : 199275, Gen Loss Total : 26.359, Mel-Spec. Error : 0.294, s/b : 1.805
# Steps : 199280, Gen Loss Total : 29.251, Mel-Spec. Error : 0.289, s/b : 1.804
# Steps : 199285, Gen Loss Total : 27.575, Mel-Spec. Error : 0.295, s/b : 1.804
# Steps : 199290, Gen Loss Total : 27.366, Mel-Spec. Error : 0.290, s/b : 1.806
# Steps : 199295, Gen Loss Total : 28.520, Mel-Spec. Error : 0.296, s/b : 1.803
# Steps : 199300, Gen Loss Total : 28.367, Mel-Spec. Error : 0.293, s/b : 1.803
# Steps : 199305, Gen Loss Total : 26.711, Mel-Spec. Error : 0.297, s/b : 1.802
# Steps : 199310, Gen Loss Total : 26.731, Mel-Spec. Error : 0.294, s/b : 1.808
# Steps : 199315, Gen Loss Total : 28.299, Mel-Spec. Error : 0.294, s/b : 1.804
# Steps : 199320, Gen Loss Total : 28.185, Mel-Spec. Error : 0.295, s/b : 1.803
# Steps : 199325, Gen Loss Total : 27.556, Mel-Spec. Error : 0.289, s/b : 1.800
# Steps : 199330, Gen Loss Total : 27.059, Mel-Spec. Error : 0.278, s/b : 1.802
# Steps : 199335, Gen Loss Total : 28.771, Mel-Spec. Error : 0.299, s/b : 1.809
# Steps : 199340, Gen Loss Total : 27.351, Mel-Spec. Error : 0.282, s/b : 1.805
# Steps : 199345, Gen Loss Total : 27.472, Mel-Spec. Error : 0.296, s/b : 1.803
# Steps : 199350, Gen Loss Total : 28.433, Mel-Spec. Error : 0.300, s/b : 1.804
# Steps : 199355, Gen Loss Total : 27.409, Mel-Spec. Error : 0.292, s/b : 1.806
# Steps : 199360, Gen Loss Total : 27.114, Mel-Spec. Error : 0.286, s/b : 1.802
# Steps : 199365, Gen Loss Total : 25.523, Mel-Spec. Error : 0.288, s/b : 1.806
# Steps : 199370, Gen Loss Total : 27.089, Mel-Spec. Error : 0.290, s/b : 1.806
# Steps : 199375, Gen Loss Total : 29.052, Mel-Spec. Error : 0.292, s/b : 1.799
# Steps : 199380, Gen Loss Total : 26.940, Mel-Spec. Error : 0.288, s/b : 1.806
# Steps : 199385, Gen Loss Total : 27.579, Mel-Spec. Error : 0.292, s/b : 1.801
# Steps : 199390, Gen Loss Total : 28.515, Mel-Spec. Error : 0.301, s/b : 1.804
# Steps : 199395, Gen Loss Total : 28.192, Mel-Spec. Error : 0.296, s/b : 1.801
# Steps : 199400, Gen Loss Total : 27.057, Mel-Spec. Error : 0.286, s/b : 1.801
# Steps : 199405, Gen Loss Total : 27.495, Mel-Spec. Error : 0.287, s/b : 1.803
# Steps : 199410, Gen Loss Total : 27.964, Mel-Spec. Error : 0.297, s/b : 1.807
# Steps : 199415, Gen Loss Total : 28.559, Mel-Spec. Error : 0.287, s/b : 1.801
# Steps : 199420, Gen Loss Total : 28.963, Mel-Spec. Error : 0.298, s/b : 1.799
# Steps : 199425, Gen Loss Total : 27.212, Mel-Spec. Error : 0.289, s/b : 1.798
# Steps : 199430, Gen Loss Total : 25.320, Mel-Spec. Error : 0.274, s/b : 1.799
# Steps : 199435, Gen Loss Total : 27.562, Mel-Spec. Error : 0.274, s/b : 1.807
# Steps : 199440, Gen Loss Total : 26.393, Mel-Spec. Error : 0.277, s/b : 1.799
# Steps : 199445, Gen Loss Total : 28.380, Mel-Spec. Error : 0.277, s/b : 1.806
# Steps : 199450, Gen Loss Total : 27.465, Mel-Spec. Error : 0.287, s/b : 1.804
# Steps : 199455, Gen Loss Total : 26.686, Mel-Spec. Error : 0.280, s/b : 1.797
# Steps : 199460, Gen Loss Total : 25.755, Mel-Spec. Error : 0.276, s/b : 1.802
# Steps : 199465, Gen Loss Total : 27.516, Mel-Spec. Error : 0.285, s/b : 1.802
# Steps : 199470, Gen Loss Total : 26.090, Mel-Spec. Error : 0.298, s/b : 1.809
# Steps : 199475, Gen Loss Total : 27.368, Mel-Spec. Error : 0.292, s/b : 1.804
# Steps : 199480, Gen Loss Total : 28.670, Mel-Spec. Error : 0.293, s/b : 1.804
# Steps : 199485, Gen Loss Total : 30.407, Mel-Spec. Error : 0.293, s/b : 1.803
# Steps : 199490, Gen Loss Total : 31.493, Mel-Spec. Error : 0.297, s/b : 1.803
# Steps : 199495, Gen Loss Total : 29.915, Mel-Spec. Error : 0.293, s/b : 1.808
# Steps : 199500, Gen Loss Total : 28.515, Mel-Spec. Error : 0.299, s/b : 1.916
# Steps : 199505, Gen Loss Total : 28.310, Mel-Spec. Error : 0.291, s/b : 1.799
# Steps : 199510, Gen Loss Total : 28.487, Mel-Spec. Error : 0.276, s/b : 1.800
# Steps : 199515, Gen Loss Total : 27.860, Mel-Spec. Error : 0.286, s/b : 1.803
# Steps : 199520, Gen Loss Total : 27.774, Mel-Spec. Error : 0.285, s/b : 1.797
# Steps : 199525, Gen Loss Total : 28.305, Mel-Spec. Error : 0.290, s/b : 1.800
# Steps : 199530, Gen Loss Total : 29.513, Mel-Spec. Error : 0.284, s/b : 1.798
# Steps : 199535, Gen Loss Total : 28.101, Mel-Spec. Error : 0.281, s/b : 1.799
# Steps : 199540, Gen Loss Total : 26.213, Mel-Spec. Error : 0.279, s/b : 1.802
# Steps : 199545, Gen Loss Total : 29.552, Mel-Spec. Error : 0.294, s/b : 1.799
# Steps : 199550, Gen Loss Total : 28.851, Mel-Spec. Error : 0.279, s/b : 1.803
# Steps : 199555, Gen Loss Total : 27.807, Mel-Spec. Error : 0.285, s/b : 1.801
# Time taken for epoch 329 is 1117 sec
#
# Epoch: 330
# Steps : 199560, Gen Loss Total : 28.197, Mel-Spec. Error : 0.300, s/b : 1.805
# Steps : 199565, Gen Loss Total : 28.228, Mel-Spec. Error : 0.296, s/b : 1.805
# Steps : 199570, Gen Loss Total : 28.827, Mel-Spec. Error : 0.302, s/b : 1.805
# Steps : 199575, Gen Loss Total : 28.952, Mel-Spec. Error : 0.302, s/b : 1.805
# Steps : 199580, Gen Loss Total : 28.991, Mel-Spec. Error : 0.295, s/b : 1.801
# Steps : 199585, Gen Loss Total : 27.135, Mel-Spec. Error : 0.288, s/b : 1.805
# Steps : 199590, Gen Loss Total : 25.935, Mel-Spec. Error : 0.282, s/b : 1.795
# Steps : 199595, Gen Loss Total : 28.585, Mel-Spec. Error : 0.307, s/b : 1.808
# Steps : 199600, Gen Loss Total : 27.070, Mel-Spec. Error : 0.289, s/b : 1.797
# Steps : 199605, Gen Loss Total : 26.890, Mel-Spec. Error : 0.288, s/b : 1.800
# Steps : 199610, Gen Loss Total : 27.648, Mel-Spec. Error : 0.288, s/b : 1.800
# Steps : 199615, Gen Loss Total : 28.231, Mel-Spec. Error : 0.291, s/b : 1.804
# Steps : 199620, Gen Loss Total : 27.230, Mel-Spec. Error : 0.288, s/b : 1.802
# Steps : 199625, Gen Loss Total : 27.433, Mel-Spec. Error : 0.278, s/b : 1.797
# Steps : 199630, Gen Loss Total : 27.405, Mel-Spec. Error : 0.300, s/b : 1.802
# Steps : 199635, Gen Loss Total : 28.681, Mel-Spec. Error : 0.297, s/b : 1.798
# Steps : 199640, Gen Loss Total : 26.727, Mel-Spec. Error : 0.284, s/b : 1.802
# Steps : 199645, Gen Loss Total : 29.594, Mel-Spec. Error : 0.291, s/b : 1.803
# Steps : 199650, Gen Loss Total : 27.454, Mel-Spec. Error : 0.286, s/b : 1.801
# Steps : 199655, Gen Loss Total : 27.178, Mel-Spec. Error : 0.290, s/b : 1.806
# Steps : 199660, Gen Loss Total : 27.988, Mel-Spec. Error : 0.291, s/b : 1.806
# Steps : 199665, Gen Loss Total : 30.086, Mel-Spec. Error : 0.296, s/b : 1.805
# Steps : 199670, Gen Loss Total : 29.424, Mel-Spec. Error : 0.295, s/b : 1.807
# Steps : 199675, Gen Loss Total : 28.764, Mel-Spec. Error : 0.302, s/b : 1.802
# Steps : 199680, Gen Loss Total : 28.305, Mel-Spec. Error : 0.300, s/b : 1.806
# Steps : 199685, Gen Loss Total : 29.484, Mel-Spec. Error : 0.302, s/b : 1.803
# Steps : 199690, Gen Loss Total : 28.572, Mel-Spec. Error : 0.286, s/b : 1.805
# Steps : 199695, Gen Loss Total : 29.689, Mel-Spec. Error : 0.302, s/b : 1.804
# Steps : 199700, Gen Loss Total : 27.283, Mel-Spec. Error : 0.308, s/b : 1.800
# Steps : 199705, Gen Loss Total : 26.760, Mel-Spec. Error : 0.282, s/b : 1.805
# Steps : 199710, Gen Loss Total : 27.814, Mel-Spec. Error : 0.287, s/b : 1.800
# Steps : 199715, Gen Loss Total : 26.833, Mel-Spec. Error : 0.289, s/b : 1.801
# Steps : 199720, Gen Loss Total : 27.305, Mel-Spec. Error : 0.281, s/b : 1.798
# Steps : 199725, Gen Loss Total : 28.039, Mel-Spec. Error : 0.288, s/b : 1.799
# Steps : 199730, Gen Loss Total : 28.938, Mel-Spec. Error : 0.293, s/b : 1.802
# Steps : 199735, Gen Loss Total : 27.717, Mel-Spec. Error : 0.291, s/b : 1.796
# Steps : 199740, Gen Loss Total : 27.100, Mel-Spec. Error : 0.288, s/b : 1.801
# Steps : 199745, Gen Loss Total : 27.293, Mel-Spec. Error : 0.294, s/b : 1.800
# Steps : 199750, Gen Loss Total : 28.787, Mel-Spec. Error : 0.293, s/b : 1.805
# Steps : 199755, Gen Loss Total : 28.608, Mel-Spec. Error : 0.294, s/b : 1.805
# Steps : 199760, Gen Loss Total : 27.264, Mel-Spec. Error : 0.293, s/b : 1.807
# Steps : 199765, Gen Loss Total : 28.601, Mel-Spec. Error : 0.295, s/b : 1.805
# Steps : 199770, Gen Loss Total : 26.902, Mel-Spec. Error : 0.279, s/b : 1.804
# Steps : 199775, Gen Loss Total : 27.035, Mel-Spec. Error : 0.293, s/b : 1.804
# Steps : 199780, Gen Loss Total : 27.199, Mel-Spec. Error : 0.281, s/b : 1.802
# Steps : 199785, Gen Loss Total : 29.168, Mel-Spec. Error : 0.288, s/b : 1.800
# Steps : 199790, Gen Loss Total : 28.227, Mel-Spec. Error : 0.298, s/b : 1.802
# Steps : 199795, Gen Loss Total : 25.922, Mel-Spec. Error : 0.284, s/b : 1.799
# Steps : 199800, Gen Loss Total : 28.847, Mel-Spec. Error : 0.305, s/b : 1.801
# Steps : 199805, Gen Loss Total : 28.991, Mel-Spec. Error : 0.309, s/b : 1.810
# Steps : 199810, Gen Loss Total : 28.789, Mel-Spec. Error : 0.307, s/b : 1.804
# Steps : 199815, Gen Loss Total : 26.961, Mel-Spec. Error : 0.298, s/b : 1.805
# Steps : 199820, Gen Loss Total : 27.801, Mel-Spec. Error : 0.287, s/b : 1.800
# Steps : 199825, Gen Loss Total : 27.623, Mel-Spec. Error : 0.286, s/b : 1.803
# Steps : 199830, Gen Loss Total : 28.350, Mel-Spec. Error : 0.300, s/b : 1.800
# Steps : 199835, Gen Loss Total : 27.183, Mel-Spec. Error : 0.270, s/b : 1.799
# Steps : 199840, Gen Loss Total : 28.272, Mel-Spec. Error : 0.298, s/b : 1.800
# Steps : 199845, Gen Loss Total : 27.351, Mel-Spec. Error : 0.285, s/b : 1.804
# Steps : 199850, Gen Loss Total : 26.934, Mel-Spec. Error : 0.294, s/b : 1.815
# Steps : 199855, Gen Loss Total : 28.349, Mel-Spec. Error : 0.297, s/b : 1.826
# Steps : 199860, Gen Loss Total : 26.492, Mel-Spec. Error : 0.291, s/b : 1.820
# Steps : 199865, Gen Loss Total : 26.716, Mel-Spec. Error : 0.289, s/b : 1.821
# Steps : 199870, Gen Loss Total : 27.733, Mel-Spec. Error : 0.301, s/b : 1.829
# Steps : 199875, Gen Loss Total : 27.598, Mel-Spec. Error : 0.304, s/b : 1.813
# Steps : 199880, Gen Loss Total : 27.353, Mel-Spec. Error : 0.281, s/b : 1.816
# Steps : 199885, Gen Loss Total : 26.357, Mel-Spec. Error : 0.280, s/b : 1.809
# Steps : 199890, Gen Loss Total : 29.056, Mel-Spec. Error : 0.299, s/b : 1.818
# Steps : 199895, Gen Loss Total : 26.194, Mel-Spec. Error : 0.288, s/b : 1.818
# Steps : 199900, Gen Loss Total : 28.081, Mel-Spec. Error : 0.294, s/b : 1.820
# Steps : 199905, Gen Loss Total : 27.790, Mel-Spec. Error : 0.295, s/b : 1.814
# Steps : 199910, Gen Loss Total : 29.002, Mel-Spec. Error : 0.301, s/b : 1.820
# Steps : 199915, Gen Loss Total : 27.380, Mel-Spec. Error : 0.284, s/b : 1.816
# Steps : 199920, Gen Loss Total : 30.210, Mel-Spec. Error : 0.296, s/b : 1.823
# Steps : 199925, Gen Loss Total : 28.446, Mel-Spec. Error : 0.287, s/b : 1.826
# Steps : 199930, Gen Loss Total : 25.783, Mel-Spec. Error : 0.292, s/b : 1.818
# Steps : 199935, Gen Loss Total : 27.357, Mel-Spec. Error : 0.300, s/b : 1.826
# Steps : 199940, Gen Loss Total : 29.432, Mel-Spec. Error : 0.313, s/b : 1.811
# Steps : 199945, Gen Loss Total : 26.056, Mel-Spec. Error : 0.305, s/b : 1.813
# Steps : 199950, Gen Loss Total : 26.741, Mel-Spec. Error : 0.291, s/b : 1.812
# Steps : 199955, Gen Loss Total : 28.084, Mel-Spec. Error : 0.296, s/b : 1.819
# Steps : 199960, Gen Loss Total : 30.511, Mel-Spec. Error : 0.299, s/b : 1.820
# Steps : 199965, Gen Loss Total : 29.312, Mel-Spec. Error : 0.290, s/b : 1.823
# Steps : 199970, Gen Loss Total : 27.594, Mel-Spec. Error : 0.298, s/b : 1.821
# Steps : 199975, Gen Loss Total : 28.776, Mel-Spec. Error : 0.293, s/b : 1.811
# Steps : 199980, Gen Loss Total : 27.822, Mel-Spec. Error : 0.292, s/b : 1.810
# Steps : 199985, Gen Loss Total : 27.707, Mel-Spec. Error : 0.272, s/b : 1.808
# Steps : 199990, Gen Loss Total : 26.932, Mel-Spec. Error : 0.288, s/b : 1.815
# Steps : 199995, Gen Loss Total : 29.309, Mel-Spec. Error : 0.286, s/b : 1.812
# Steps : 200000, Gen Loss Total : 27.523, Mel-Spec. Error : 0.296, s/b : 2.105
# Saving checkpoint to cp_hifigan/g_00200000
# Complete.
# Saving checkpoint to cp_hifigan/do_00200000
# Complete.
# val err tot:  0.27263020259141924
# Steps : 200005, Gen Loss Total : 29.470, Mel-Spec. Error : 0.307, s/b : 1.817
# Steps : 200010, Gen Loss Total : 27.991, Mel-Spec. Error : 0.293, s/b : 1.805
# Steps : 200015, Gen Loss Total : 28.580, Mel-Spec. Error : 0.292, s/b : 1.809
# Steps : 200020, Gen Loss Total : 27.545, Mel-Spec. Error : 0.283, s/b : 1.810
# Steps : 200025, Gen Loss Total : 28.628, Mel-Spec. Error : 0.301, s/b : 1.813
# Steps : 200030, Gen Loss Total : 26.495, Mel-Spec. Error : 0.281, s/b : 1.820
# Steps : 200035, Gen Loss Total : 28.864, Mel-Spec. Error : 0.293, s/b : 1.822
# Steps : 200040, Gen Loss Total : 28.628, Mel-Spec. Error : 0.293, s/b : 1.822
# Steps : 200045, Gen Loss Total : 28.079, Mel-Spec. Error : 0.298, s/b : 1.823
# Steps : 200050, Gen Loss Total : 27.483, Mel-Spec. Error : 0.280, s/b : 1.823
# Steps : 200055, Gen Loss Total : 28.508, Mel-Spec. Error : 0.286, s/b : 1.817
# Steps : 200060, Gen Loss Total : 26.401, Mel-Spec. Error : 0.284, s/b : 1.823
# Steps : 200065, Gen Loss Total : 27.609, Mel-Spec. Error : 0.281, s/b : 1.819
# Steps : 200070, Gen Loss Total : 26.082, Mel-Spec. Error : 0.281, s/b : 1.819
# Steps : 200075, Gen Loss Total : 28.433, Mel-Spec. Error : 0.289, s/b : 1.813
# Steps : 200080, Gen Loss Total : 29.162, Mel-Spec. Error : 0.297, s/b : 1.820
# Steps : 200085, Gen Loss Total : 29.792, Mel-Spec. Error : 0.302, s/b : 1.815
# Steps : 200090, Gen Loss Total : 29.386, Mel-Spec. Error : 0.291, s/b : 1.814
# Steps : 200095, Gen Loss Total : 29.043, Mel-Spec. Error : 0.303, s/b : 1.816
# Steps : 200100, Gen Loss Total : 29.105, Mel-Spec. Error : 0.286, s/b : 1.821
# Steps : 200105, Gen Loss Total : 29.155, Mel-Spec. Error : 0.281, s/b : 1.818
# Steps : 200110, Gen Loss Total : 26.168, Mel-Spec. Error : 0.283, s/b : 1.812
# Steps : 200115, Gen Loss Total : 27.300, Mel-Spec. Error : 0.277, s/b : 1.815
# Steps : 200120, Gen Loss Total : 27.652, Mel-Spec. Error : 0.289, s/b : 1.822
# Steps : 200125, Gen Loss Total : 28.815, Mel-Spec. Error : 0.287, s/b : 1.814
# Steps : 200130, Gen Loss Total : 28.218, Mel-Spec. Error : 0.295, s/b : 1.819
# Steps : 200135, Gen Loss Total : 27.448, Mel-Spec. Error : 0.274, s/b : 1.814
# Steps : 200140, Gen Loss Total : 25.127, Mel-Spec. Error : 0.271, s/b : 1.821
# Steps : 200145, Gen Loss Total : 26.207, Mel-Spec. Error : 0.280, s/b : 1.821
# Steps : 200150, Gen Loss Total : 29.082, Mel-Spec. Error : 0.291, s/b : 1.823
# Time taken for epoch 330 is 1124 sec
#
# Epoch: 331
# Steps : 200155, Gen Loss Total : 29.911, Mel-Spec. Error : 0.313, s/b : 1.821
# Steps : 200160, Gen Loss Total : 26.150, Mel-Spec. Error : 0.287, s/b : 1.820
# Steps : 200165, Gen Loss Total : 26.468, Mel-Spec. Error : 0.285, s/b : 1.817
# Steps : 200170, Gen Loss Total : 27.729, Mel-Spec. Error : 0.292, s/b : 1.820
# Steps : 200175, Gen Loss Total : 29.253, Mel-Spec. Error : 0.296, s/b : 1.824
# Steps : 200180, Gen Loss Total : 26.911, Mel-Spec. Error : 0.294, s/b : 1.820
# Steps : 200185, Gen Loss Total : 29.825, Mel-Spec. Error : 0.300, s/b : 1.823
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-d2ec72709091> in <module>()
# ----> 1 train(0, a, h)
#
# <ipython-input-7-8e0716a12400> in train(rank, a, h)
#     148             # print('loss_gen_all: ', loss_gen_all)
#     149
# --> 150             loss_gen_all.backward()
#     151             optim_g.step()
#     152
#
# /usr/local/lib/python3.7/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     193                 products. Defaults to ``False``.
#     194         """
# --> 195         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     196
#     197     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %% [markdown]
# ### Test Infer (vocoder itself)

# %%
import glob
import os
import argparse
import json
import torch
from scipy.io.wavfile import write
from env import AttrDict
from meldataset import mel_spectrogram, MAX_WAV_VALUE, load_wav
from models import Generator

h = None
device = None

def load_checkpoint(filepath, device):
    assert os.path.isfile(filepath)
    print("Loading '{}'".format(filepath))
    checkpoint_dict = torch.load(filepath, map_location=device)
    print("Complete.")
    return checkpoint_dict


def get_mel(x):
    return mel_spectrogram(x, h.n_fft, h.num_mels, h.sampling_rate, h.hop_size, h.win_size, h.fmin, h.fmax)


def scan_checkpoint(cp_dir, prefix):
    pattern = os.path.join(cp_dir, prefix + '*')
    cp_list = glob.glob(pattern)
    if len(cp_list) == 0:
        return ''
    return sorted(cp_list)[-1]


def inference(a):
    generator = Generator(h).to(device)

    state_dict_g = load_checkpoint(a.checkpoint_file, device)
    generator.load_state_dict(state_dict_g['generator'])

    filelist = os.listdir(a.input_wavs_dir)

    os.makedirs(a.output_dir, exist_ok=True)

    generator.eval()
    generator.remove_weight_norm()
    with torch.no_grad():
        for i, filname in enumerate(filelist):
            wav, sr = load_wav(os.path.join(a.input_wavs_dir, filname))
            wav = wav / MAX_WAV_VALUE
            wav = torch.FloatTensor(wav).to(device)
            x = get_mel(wav.unsqueeze(0))
            
            y_g_hat = generator(x)
            audio = y_g_hat.squeeze()
            audio = audio * MAX_WAV_VALUE
            audio = audio.cpu().numpy().astype('int16')

            output_file = os.path.join(a.output_dir, os.path.splitext(filname)[0] + '_generated.wav')
            write(output_file, h.sampling_rate, audio)
            print(output_file)

# %%
print('Initializing Inference Process..')

a = easydict.EasyDict({ "group_name": None , 
                        "input_wavs_dir": "/content/drive/MyDrive/tts_hifiGAN/dataset/wav_data",
                        "output_dir": "/content/drive/MyDrive/tts_hifiGAN/output_result",
                        "checkpoint_file" : "/content/drive/MyDrive/tts_hifiGAN/hifi-gan/cp_hifigan/g_00162000",
                       # "checkpoint_file" : "/content/drive/MyDrive/tts_hifiGAN/hifi-gan/cp_hifigan/univ/g_02511000"
                        })


config_file = "/content/drive/MyDrive/tts_hifiGAN/hifi-gan/cp_hifigan/config.json"

with open(config_file) as f:
    data = f.read()

# %%
global h
json_config = json.loads(data)
h = AttrDict(json_config)

torch.manual_seed(h.seed)
global device
if torch.cuda.is_available():
    torch.cuda.manual_seed(h.seed)
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

inference(a)

# %%
from scipy.io import wavfile
import IPython.display as ipd

path = "/content/drive/MyDrive/tts_hifiGAN/output_result/9005_generated.wav"

fs, data = wavfile.read(path)
ipd.Audio(data, rate=22050)

# %% [markdown]
# ### Test Infer (mel-spectrogram from Tacotron2)

# %%
import glob
import os
import easydict
import numpy as np
import argparse
import json
import torch
from scipy.io.wavfile import write
from env import AttrDict
from meldataset import MAX_WAV_VALUE
from models import Generator

h = None
device = None


def load_checkpoint(filepath, device):
    assert os.path.isfile(filepath)
    print("Loading '{}'".format(filepath))
    checkpoint_dict = torch.load(filepath, map_location=device)
    print("Complete.")
    return checkpoint_dict


def scan_checkpoint(cp_dir, prefix):
    pattern = os.path.join(cp_dir, prefix + '*')
    cp_list = glob.glob(pattern)
    if len(cp_list) == 0:
        return ''
    return sorted(cp_list)[-1]


def inference(a):
    generator = Generator(h).to(device)

    state_dict_g = load_checkpoint(a.checkpoint_file, device)
    generator.load_state_dict(state_dict_g['generator'])

    filelist = os.listdir(a.input_mels_dir)

    os.makedirs(a.output_dir, exist_ok=True)

    generator.eval()
    generator.remove_weight_norm()
    with torch.no_grad():
        for i, filname in enumerate(filelist):
            x = np.load(os.path.join(a.input_mels_dir, filname))
            x = torch.FloatTensor(x).to(device)
            
            
            if len(x.shape) == 2:
              
              x = x.unsqueeze(0)
              print('축 변환 완료 ')
              print('\n')

            y_g_hat = generator(x)
            audio = y_g_hat.squeeze()
            audio = audio * MAX_WAV_VALUE
            audio = audio.cpu().numpy().astype('int16')

            output_file = os.path.join(a.output_dir, os.path.splitext(filname)[0] + '_generated_e2e.wav')
            write(output_file, h.sampling_rate, audio)
            print(output_file)
# Out:
# /usr/local/lib/python3.7/dist-packages/resampy/interpn.py:114: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   _resample_loop_p(x, t_out, interp_win, interp_delta, num_table, scale, y)

# %%
print('Initializing Inference Process..')

a = easydict.EasyDict({ 
                        "input_mels_dir": "/content/drive/MyDrive/tts_hifiGAN/dataset/mel_data/bye",
                        # "input_mels_dir": "/content/drive/MyDrive/tts_hifiGAN/dataset/mel_data/second",
                        "output_dir": "/content/drive/MyDrive/tts_hifiGAN/USING_output/bye",
                        "checkpoint_file" : "/content/drive/MyDrive/tts_hifiGAN/hifi-gan/cp_hifigan/g_00200000",
                        # "checkpoint_file" : "/content/drive/MyDrive/tts_hifiGAN/hifi-gan/cp_hifigan/univ/g_02500000"
                        })


config_file = "/content/drive/MyDrive/tts_hifiGAN/hifi-gan/cp_hifigan/config.json"

with open(config_file) as f:
    data = f.read()
# Out:
# Initializing Inference Process..

# %%
global h
json_config = json.loads(data)
h = AttrDict(json_config)

torch.manual_seed(h.seed)
global device
if torch.cuda.is_available():
    torch.cuda.manual_seed(h.seed)
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

inference(a)
# Out:
# Loading '/content/drive/MyDrive/tts_hifiGAN/hifi-gan/cp_hifigan/g_00200000'
# Complete.
# Removing weight norm...
# /content/drive/MyDrive/tts_hifiGAN/USING_output/bye/byebye-final-meloutput-new_generated_e2e.wav
# /content/drive/MyDrive/tts_hifiGAN/USING_output/bye/byebye-final2-meloutput-new_generated_e2e.wav
# /content/drive/MyDrive/tts_hifiGAN/USING_output/bye/byebye-final3-meloutput-new_generated_e2e.wav
# /content/drive/MyDrive/tts_hifiGAN/USING_output/bye/byebye-final4-meloutput-new_generated_e2e.wav
# /content/drive/MyDrive/tts_hifiGAN/USING_output/bye/ex1-mj-meloutput_generated_e2e.wav
# /content/drive/MyDrive/tts_hifiGAN/USING_output/bye/ex2-mj-meloutput_generated_e2e.wav
# /content/drive/MyDrive/tts_hifiGAN/USING_output/bye/ex-mj-meloutput_generated_e2e.wav

# %%
from scipy.io import wavfile
import IPython.display as ipd

path = "/content/drive/MyDrive/tts_hifiGAN/USING_output/0-meloutput-new_generated_e2e.wav"

fs, data = wavfile.read(path)
ipd.Audio(data, rate=22050)

# %% [markdown]
# pytorch 공식 튜토리올 --> mel-spec (En) 버전 test가능
# https://pytorch.org/hub/nvidia_deeplearningexamples_tacotron2/
# https://colab.research.google.com/drive/1auDqb-MzrIexPW87v1fEqVnnzAGFvwOG?usp=sharing (적용)

# %% [markdown]
# 한국어 pretrained FastSpeech checkpoint 있음
# https://github.com/HGU-DLLAB/Korean-FastSpeech2-Pytorch

# %% [markdown]
# 한국어 End to End pretrained chekcpoint 있음.(huggingface) Tacotron2 + MelGAN
# https://github.com/TensorSpeech/TensorFlowTTS/issues/183
# https://colab.research.google.com/drive/1ybWwOS5tipgPFttNulp77P6DAB5MtiuN?usp=sharing#scrollTo=0wzU9yQElSDK

# %% [markdown]
# jss tacotron2 한국어 학습. 결과 잘 나온건지는 모르겟음
# https://colab.research.google.com/drive/18iRei4P9x0kiO2ZQ1V6KXPJ3MSurGCC6?hl=ko#scrollTo=eJYtqvGRwDzb

# %%
import librosa
tmp = np.load("/content/drive/MyDrive/tts_hifiGAN/dataset/mel_data/0-meloutput-new (1).npy")
tmp = tmp.squeeze(0)
wav_data = librosa.feature.inverse.mel_to_audio(tmp, sr=22050)
import soundfile

soundfile.write(file="tmp.wav",data=wav_data, samplerate=22050)
from scipy.io import wavfile
import IPython.display as ipd

fs, data = wavfile.read("tmp.wav")
ipd.Audio(data, rate=22050)
